# %%
# !nvidia-smi
# Out:
# Sat May  4 16:36:38 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    26W /  70W |   3065MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#https://drive.google.com/open?id=1zglOX-AkDkXV3SAiUcQEm0gssYF3FrVZ

download = drive.CreateFile({'id': '1zglOX-AkDkXV3SAiUcQEm0gssYF3FrVZ'})
download.GetContentFile('Flickr8k.zip')
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.5)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (1.12.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.5)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.11.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)

# %%
# !unzip Flickr8k.zip

# %% [markdown]
# # InceptionResnetV2Fasttext

# %%
#https://drive.google.com/open?id=1gL1hvfsYTWr5QTdOVBrRkGMXbIc8cHRC
download = drive.CreateFile({'id': '1gL1hvfsYTWr5QTdOVBrRkGMXbIc8cHRC'})
download.GetContentFile('model-ep003-loss3.360-val_loss3.631.h5')

#https://drive.google.com/open?id=1a-IDaIMX52znZCeuBxwC58D4j3J85cKB
download = drive.CreateFile({'id': '1a-IDaIMX52znZCeuBxwC58D4j3J85cKB'})
download.GetContentFile('features12.pkl')

#https://drive.google.com/open?id=19h2TfPUCCZgHsnFaZz4iSH66-9IUp79M
download = drive.CreateFile({'id': '19h2TfPUCCZgHsnFaZz4iSH66-9IUp79M'})
download.GetContentFile('descriptions12.txt')

#https://drive.google.com/open?id=1FMLmyRzKo6sym_4SaQqXcOsXaUVKj0-I
download = drive.CreateFile({'id': '1FMLmyRzKo6sym_4SaQqXcOsXaUVKj0-I'})
download.GetContentFile('tokenizer12.pkl')

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

import io
import zipfile
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import pickle
import numpy as np

def load_doc(fname):
  fp=open(fname,'r')
  txt=fp.read()
  fp.close()
  return txt

fname='Flickr8k/Flickr8k_text/Flickr8k.token.txt'
doc=load_doc(fname)

def evaluate_model(model,descriptions,photos,tokenizer,max_len):
  rd={}
  actual,predicted=list(),list()
  for key,desc_list in descriptions.items():
    yhat=generate_desc(model,tokenizer,photos[key],max_len)
    
    references=[d.split() for d in desc_list]
    
    rd[key]=(references,yhat.split())
  
    actual.append(references)
    predicted.append(yhat.split())
    
    
  return actual,predicted,rd

def word_for_id(integer,tokenizer):
  for word,index in tokenizer.word_index.items():
    if index==integer:
      return word
  return None
  
def generate_desc(model,tokenizer,photo,max_len):
  in_text='startseq'
  
  for i in range(max_len):
    sequence=tokenizer.texts_to_sequences([in_text])[0]
    
    sequence=pad_sequences([sequence],maxlen=max_len)
    
    yhat=model.predict([photo,sequence],verbose=0)
    yhat=np.argmax(yhat)
    
    word=word_for_id(yhat,tokenizer)
    
    if word is None:
      break
      
    in_text += ' '+word
    
    if word=='endseq':
      break
      
  return in_text

def load_set(fname):
  doc=load_doc(fname)
  dataset=list()
  for line in doc.split('\n'):
    if len(line)<1:
      continue
    identifier=line.split('.')[0]
    dataset.append(identifier)

  return dataset,set(dataset)

def load_clean_descriptions(fname,dataset):
  doc=load_doc(fname)
  descriptions = dict()
  for line in doc.split('\n'):
    tokens=line.split()
    img_id,img_desc=tokens[0],tokens[1:]
    if img_id in dataset:
      if img_id not in descriptions:
        descriptions[img_id]=list()
      
      desc='startseq ' + ' '.join(img_desc) + ' endseq'
      #print(img_id,img_desc)
      descriptions[img_id].append(desc)
      #print(img_id,descriptions[img_id])
  
  return descriptions

def load_photo_features(fname,dataset):
  all_features=pickle.load(open(fname,'rb'))
  features={k:all_features[k] for k in dataset}
  return features

fname='Flickr8k/Flickr8k_text/Flickr_8k.testImages.txt'
testlist,test=load_set(fname)
print(len(testlist),len(test))
test_descriptions=load_clean_descriptions('descriptions12.txt',testlist)
print(len(test_descriptions))
test_features=load_photo_features('features12.pkl',testlist)
print(len(test_features))
# Out:
# 1000 1000
# 1000
# 1000

# %%
len(testlist)
# Out:
# 1000

# %%
import numpy as np
import pandas as pd
import cv2
import time
import os
import matplotlib.pyplot as plt
import pickle
import string

from keras.applications.inception_resnet_v2 import InceptionResNetV2,preprocess_input

#from keras.applications.vgg16 import VGG16,preprocess_input
from keras.preprocessing.image import load_img,img_to_array
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical,plot_model
from keras.models import Model
from keras.layers import Input,Dense,LSTM,Embedding,Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu
#import shutil #dont use shutil it deletes files
from collections import Counter
# Out:
# Using TensorFlow backend.

# %%
tokenizer=pickle.load(open('tokenizer12.pkl','rb'))

# %%
max_len=34

# %%
# test set
start=time.time()
InceptionResnetV2Fasttext=load_model('model-ep003-loss3.360-val_loss3.631.h5')
actual,predicted,rd_test=evaluate_model(InceptionResnetV2Fasttext,test_descriptions,test_features,tokenizer,max_len)
end=time.time()
print(end-start)
print('BLEU - 1 : %f' % corpus_bleu(actual,predicted,weights=(1.0,0,0,0)))
print('BLEU - 2 : %f' % corpus_bleu(actual,predicted,weights=(0.5,0.5,0,0)))
print('BLEU - 3 : %f' % corpus_bleu(actual,predicted,weights=(0.3,0.3,0.3,0)))
print('BLEU - 4 : %f' % corpus_bleu(actual,predicted,weights=(0.25,0.25,0.25,0.25)))
print(len(actual),len(predicted))
pickle.dump(actual,open('actual.pkl','wb'))
pickle.dump(predicted,open('predicted.pkl','wb'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 212.2106409072876
# BLEU - 1 : 0.548384
# BLEU - 2 : 0.306833
# BLEU - 3 : 0.213625
# BLEU - 4 : 0.103650
# 1000 1000

# %%
rd_test
# Out:
# {'1056338697_4f7d7ce270': ([['startseq',
#     'blond',
#     'woman',
#     'in',
#     'blue',
#     'shirt',
#     'appears',
#     'to',
#     'wait',
#     'for',
#     'ride',
#     'endseq'],
#    ['startseq',
#     'blond',
#     'woman',
#     'is',
#     'on',
#     'the',
#     'street',
#     'hailing',
#     'taxi',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'is',
#     'signaling',
#     'is',
#     'to',
#     'traffic',
#     'as',
#     'seen',
#     'from',
#     'behind',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'with',
#     'blonde',
#     'hair',
#     'wearing',
#     'blue',
#     'tube',
#     'top',
#     'is',
#     'waving',
#     'on',
#     'the',
#     'side',
#     'of',
#     'the',
#     'street',
#     'endseq'],
#    ['startseq',
#     'the',
#     'woman',
#     'in',
#     'the',
#     'blue',
#     'dress',
#     'is',
#     'holding',
#     'out',
#     'her',
#     'arm',
#     'at',
#     'oncoming',
#     'traffic',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '106490881_5a2dd9b7bd': ([['startseq',
#     'boy',
#     'in',
#     'his',
#     'blue',
#     'swim',
#     'shorts',
#     'at',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'smiles',
#     'for',
#     'the',
#     'camera',
#     'at',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'in',
#     'swimming',
#     'trunks',
#     'is',
#     'walking',
#     'with',
#     'his',
#     'arms',
#     'outstretched',
#     'on',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq', 'children', 'playing', 'on', 'the', 'beach', 'endseq'],
#    ['startseq',
#     'the',
#     'boy',
#     'is',
#     'playing',
#     'on',
#     'the',
#     'shore',
#     'of',
#     'an',
#     'ocean',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'the', 'water', 'endseq']),
#  '1082379191_ec1e53f996': ([['startseq',
#     'lady',
#     'and',
#     'man',
#     'with',
#     'no',
#     'shirt',
#     'sit',
#     'on',
#     'dock',
#     'endseq'],
#    ['startseq',
#     'man',
#     'and',
#     'woman',
#     'are',
#     'sitting',
#     'on',
#     'dock',
#     'together',
#     'endseq'],
#    ['startseq', 'man', 'and', 'woman', 'sitting', 'on', 'dock', 'endseq'],
#    ['startseq',
#     'man',
#     'and',
#     'woman',
#     'sitting',
#     'on',
#     'deck',
#     'next',
#     'to',
#     'lake',
#     'endseq'],
#    ['startseq',
#     'shirtless',
#     'man',
#     'and',
#     'woman',
#     'sitting',
#     'on',
#     'dock',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '1084040636_97d9633581': ([['startseq',
#     'closeup',
#     'of',
#     'white',
#     'dog',
#     'that',
#     'is',
#     'laying',
#     'its',
#     'head',
#     'on',
#     'its',
#     'paws',
#     'endseq'],
#    ['startseq',
#     'large',
#     'white',
#     'dog',
#     'lying',
#     'on',
#     'the',
#     'floor',
#     'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'has',
#     'its',
#     'head',
#     'on',
#     'the',
#     'ground',
#     'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'is',
#     'resting',
#     'its',
#     'head',
#     'on',
#     'tiled',
#     'floor',
#     'with',
#     'its',
#     'eyes',
#     'open',
#     'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'rests',
#     'its',
#     'head',
#     'on',
#     'the',
#     'patio',
#     'bricks',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1096395242_fc69f0ae5a': ([['startseq',
#     'boy',
#     'with',
#     'toy',
#     'gun',
#     'endseq'],
#    ['startseq',
#     'little',
#     'boy',
#     'in',
#     'orange',
#     'shorts',
#     'playing',
#     'with',
#     'toy',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'with',
#     'his',
#     'foot',
#     'outstretched',
#     'aims',
#     'toy',
#     'at',
#     'the',
#     'camera',
#     'in',
#     'front',
#     'of',
#     'fireplace',
#     'endseq'],
#    ['startseq',
#     'young',
#     'child',
#     'plays',
#     'with',
#     'his',
#     'new',
#     'lightup',
#     'toy',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'with',
#     'toy',
#     'gun',
#     'pointed',
#     'at',
#     'the',
#     'camera',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '1107246521_d16a476380': ([['startseq',
#     'black',
#     'dog',
#     'jumping',
#     'to',
#     'catch',
#     'rope',
#     'toy',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'playing',
#     'fetch',
#     'with',
#     'ball',
#     'of',
#     'rope',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'pounces',
#     'to',
#     'get',
#     'rope',
#     'toy',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'running',
#     'after',
#     'his',
#     'rope',
#     'toy',
#     'endseq'],
#    ['startseq',
#     'large',
#     'black',
#     'dog',
#     'is',
#     'playing',
#     'in',
#     'grassy',
#     'yard',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1119015538_e8e796281e': ([['startseq',
#     'little',
#     'tan',
#     'dog',
#     'with',
#     'large',
#     'ears',
#     'running',
#     'through',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'playful',
#     'dog',
#     'is',
#     'running',
#     'through',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'small',
#     'dogs',
#     'ears',
#     'stick',
#     'up',
#     'as',
#     'it',
#     'runs',
#     'in',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'the',
#     'small',
#     'dog',
#     'is',
#     'running',
#     'across',
#     'the',
#     'lawn',
#     'endseq'],
#    ['startseq',
#     'this',
#     'is',
#     'small',
#     'beige',
#     'dog',
#     'running',
#     'through',
#     'grassy',
#     'field',
#     'endseq']],
#   ['startseq',
#    'two',
#    'dogs',
#    'are',
#    'playing',
#    'with',
#    'ball',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '1122944218_8eb3607403': ([['startseq',
#     'baby',
#     'in',
#     'white',
#     'garment',
#     'holds',
#     'flag',
#     'with',
#     'crescent',
#     'moon',
#     'and',
#     'star',
#     'endseq'],
#    ['startseq',
#     'baby',
#     'is',
#     'holding',
#     'small',
#     'black',
#     'flag',
#     'with',
#     'moon',
#     'and',
#     'star',
#     'on',
#     'it',
#     'endseq'],
#    ['startseq',
#     'baby',
#     'wearing',
#     'white',
#     'gown',
#     'waves',
#     'muslim',
#     'flag',
#     'endseq'],
#    ['startseq',
#     'little',
#     'toddler',
#     'dressed',
#     'in',
#     'white',
#     'is',
#     'smiling',
#     'while',
#     'lady',
#     'helps',
#     'him',
#     'wave',
#     'flag',
#     'endseq'],
#    ['startseq',
#     'baby',
#     'in',
#     'white',
#     'outfit',
#     'holding',
#     'black',
#     'and',
#     'white',
#     'flag',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'with',
#    'her',
#    'arms',
#    'endseq']),
#  '1131800850_89c7ffd477': ([['startseq',
#     'brown',
#     'and',
#     'white',
#     'dog',
#     'stands',
#     'outside',
#     'while',
#     'it',
#     'snows',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'is',
#     'looking',
#     'at',
#     'something',
#     'near',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'furry',
#     'dog',
#     'attempts',
#     'to',
#     'dry',
#     'itself',
#     'by',
#     'shaking',
#     'the',
#     'water',
#     'off',
#     'its',
#     'coat',
#     'endseq'],
#    ['startseq',
#     'white',
#     'and',
#     'brown',
#     'dog',
#     'shaking',
#     'its',
#     'self',
#     'dry',
#     'endseq'],
#    ['startseq',
#     'the',
#     'large',
#     'brown',
#     'and',
#     'white',
#     'dog',
#     'shakes',
#     'off',
#     'water',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1131932671_c8d17751b3': ([['startseq',
#     'boy',
#     'is',
#     'jumping',
#     'on',
#     'bed',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'jumped',
#     'up',
#     'from',
#     'the',
#     'green',
#     'bed',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'jumps',
#     'from',
#     'one',
#     'bed',
#     'to',
#     'another',
#     'endseq'],
#    ['startseq', 'small', 'child', 'is', 'jumping', 'on', 'bed', 'endseq'],
#    ['startseq',
#     'the',
#     'boy',
#     'in',
#     'blue',
#     'shorts',
#     'is',
#     'bouncing',
#     'on',
#     'the',
#     'bed',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'is',
#    'playing',
#    'with',
#    'her',
#    'arms',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '113678030_87a6a6e42e': ([['startseq',
#     'snowboarder',
#     'sits',
#     'on',
#     'slope',
#     'with',
#     'skiers',
#     'and',
#     'boarders',
#     'nearby',
#     'endseq'],
#    ['startseq',
#     'snowboarder',
#     'takes',
#     'rest',
#     'on',
#     'the',
#     'mountainside',
#     'endseq'],
#    ['startseq',
#     'snowboarders',
#     'sitting',
#     'in',
#     'the',
#     'snow',
#     'while',
#     'skiers',
#     'take',
#     'the',
#     'hill',
#     'endseq'],
#    ['startseq', 'the', 'snowboarder', 'is', 'sitting', 'down', 'endseq'],
#    ['startseq',
#     'two',
#     'skiers',
#     'stand',
#     'two',
#     'sit',
#     'on',
#     'slopes',
#     'endseq']],
#   ['startseq', 'man', 'is', 'walking', 'through', 'the', 'snow', 'endseq']),
#  '114051287_dd85625a04': ([['startseq',
#     'boy',
#     'dressed',
#     'in',
#     'soccer',
#     'attire',
#     'and',
#     'holding',
#     'his',
#     'shoes',
#     'getting',
#     'out',
#     'of',
#     'car',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'red',
#     'soccer',
#     'strip',
#     'is',
#     'holding',
#     'his',
#     'boots',
#     'in',
#     'his',
#     'hand',
#     'whilst',
#     'stepping',
#     'out',
#     'of',
#     'car',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'glasses',
#     'is',
#     'wearing',
#     'red',
#     'shirt',
#     'endseq'],
#    ['startseq',
#     'child',
#     'getting',
#     'out',
#     'of',
#     'the',
#     'car',
#     'wearing',
#     'soccer',
#     'shoes',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'gets',
#     'out',
#     'of',
#     'the',
#     'van',
#     'and',
#     'prepares',
#     'his',
#     'shoes',
#     'for',
#     'wear',
#     'during',
#     'soccer',
#     'game',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '115684808_cb01227802': ([['startseq',
#     'three',
#     'men',
#     'are',
#     'setting',
#     'up',
#     'sledge',
#     'on',
#     'snowy',
#     'plain',
#     'endseq'],
#    ['startseq', 'three', 'men', 'loading', 'items', 'on', 'sled', 'endseq'],
#    ['startseq', 'three', 'people', 'and', 'sled', 'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'are',
#     'standing',
#     'in',
#     'the',
#     'snow',
#     'preparing',
#     'an',
#     'ice',
#     'fishing',
#     'boat',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'in',
#     'the',
#     'snow',
#     'put',
#     'their',
#     'gear',
#     'in',
#     'order',
#     'endseq']],
#   ['startseq',
#    'two',
#    'people',
#    'are',
#    'playing',
#    'with',
#    'red',
#    'ball',
#    'in',
#    'the',
#    'snow',
#    'endseq']),
#  '1167669558_87a8a467d6': ([['startseq',
#     'man',
#     'in',
#     'yellow',
#     'grimaces',
#     'endseq'],
#    ['startseq',
#     'man',
#     'wearing',
#     'yellow',
#     'shirt',
#     'with',
#     'dramatic',
#     'look',
#     'on',
#     'his',
#     'face',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'in',
#     'the',
#     'yellow',
#     'tshirt',
#     'is',
#     'pulling',
#     'large',
#     'grin',
#     'on',
#     'his',
#     'face',
#     'endseq'],
#    ['startseq',
#     'there',
#     'is',
#     'man',
#     'wearing',
#     'yellow',
#     'shirt',
#     'and',
#     'grimacing',
#     'endseq'],
#    ['startseq',
#     'this',
#     'man',
#     'is',
#     'smiling',
#     'very',
#     'big',
#     'at',
#     'the',
#     'camera',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1174525839_7c1e6cfa86': ([['startseq',
#     'girl',
#     'in',
#     'blue',
#     'is',
#     'jumping',
#     'on',
#     'the',
#     'shore',
#     'as',
#     'small',
#     'waves',
#     'approach',
#     'her',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'leaps',
#     'into',
#     'the',
#     'air',
#     'while',
#     'standing',
#     'by',
#     'the',
#     'ocean',
#     'endseq'],
#    ['startseq',
#     'young',
#     'longhaired',
#     'girl',
#     'on',
#     'the',
#     'beach',
#     'is',
#     'jumping',
#     'in',
#     'the',
#     'air',
#     'endseq'],
#    ['startseq',
#     'the',
#     'girl',
#     'is',
#     'running',
#     'into',
#     'the',
#     'ocean',
#     'from',
#     'the',
#     'shore',
#     'endseq'],
#    ['startseq',
#     'the',
#     'girls',
#     'is',
#     'jumping',
#     'into',
#     'the',
#     'air',
#     'on',
#     'the',
#     'beach',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'is',
#    'jumping',
#    'into',
#    'the',
#    'water',
#    'endseq']),
#  '1174629344_a2e1a2bdbf': ([['startseq',
#     'crowd',
#     'of',
#     'people',
#     'walk',
#     'down',
#     'busy',
#     'sidewalk',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'different',
#     'people',
#     'are',
#     'walking',
#     'in',
#     'all',
#     'different',
#     'directions',
#     'in',
#     'city',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'walking',
#     'city',
#     'street',
#     'in',
#     'warm',
#     'weather',
#     'endseq'],
#    ['startseq',
#     'busy',
#     'intersection',
#     'in',
#     'the',
#     'summer',
#     'time',
#     'in',
#     'city',
#     'endseq'],
#    ['startseq',
#     'people',
#     'in',
#     'summer',
#     'clothes',
#     'are',
#     'walking',
#     'on',
#     'the',
#     'sidewalk',
#     'of',
#     'large',
#     'city',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1220401002_3f44b1f3f7': ([['startseq',
#     'two',
#     'children',
#     'are',
#     'laughing',
#     'in',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq', 'two', 'girls', 'laughing', 'outside', 'in', 'yard', 'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'standing',
#     'on',
#     'grass',
#     'face',
#     'each',
#     'other',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'girls',
#     'are',
#     'playing',
#     'and',
#     'laughing',
#     'in',
#     'green',
#     'grassy',
#     'yard',
#     'endseq'],
#    ['startseq', 'two', 'young', 'girls', 'playing', 'together', 'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'is',
#    'playing',
#    'with',
#    'her',
#    'arms',
#    'in',
#    'the',
#    'air',
#    'endseq']),
#  '1224851143_33bcdd299c': ([['startseq',
#     'boy',
#     'eats',
#     'with',
#     'spoon',
#     'endseq'],
#    ['startseq',
#     'little',
#     'boy',
#     'holds',
#     'spoon',
#     'up',
#     'to',
#     'his',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'little',
#     'boy',
#     'is',
#     'eating',
#     'his',
#     'food',
#     'off',
#     'of',
#     'spoon',
#     'while',
#     'sitting',
#     'on',
#     'patio',
#     'endseq'],
#    ['startseq',
#     'small',
#     'child',
#     'dressed',
#     'in',
#     'green',
#     'is',
#     'eating',
#     'with',
#     'spoon',
#     'endseq'],
#    ['startseq',
#     'young',
#     'child',
#     'holds',
#     'spoon',
#     'to',
#     'its',
#     'mouth',
#     'while',
#     'sitting',
#     'in',
#     'chair',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'sidewalk',
#    'endseq']),
#  '1237985362_dbafc59280': ([['startseq',
#     'lady',
#     'holds',
#     'little',
#     'girl',
#     'who',
#     'is',
#     'trying',
#     'to',
#     'catch',
#     'bubbles',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'is',
#     'holding',
#     'little',
#     'girl',
#     'who',
#     'is',
#     'trying',
#     'to',
#     'catch',
#     'bubbles',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'with',
#     'holding',
#     'young',
#     'girl',
#     'playing',
#     'with',
#     'bubbles',
#     'at',
#     'picnic',
#     'endseq'],
#    ['startseq',
#     'young',
#     'woman',
#     'in',
#     'blue',
#     'shirt',
#     'stands',
#     'holding',
#     'young',
#     'girl',
#     'in',
#     'denim',
#     'dress',
#     'endseq'],
#    ['startseq',
#     'there',
#     'is',
#     'woman',
#     'holding',
#     'her',
#     'baby',
#     'daughter',
#     'while',
#     'the',
#     'daughter',
#     'claps',
#     'endseq']],
#   ['startseq',
#    'little',
#    'boy',
#    'is',
#    'playing',
#    'with',
#    'her',
#    'eyes',
#    'endseq']),
#  '1248940539_46d33ed487': ([['startseq',
#     'three',
#     'children',
#     'are',
#     'playing',
#     'in',
#     'sand',
#     'near',
#     'to',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'three',
#     'children',
#     'playing',
#     'in',
#     'sand',
#     'at',
#     'beach',
#     'endseq'],
#    ['startseq', 'three', 'girls', 'play', 'in', 'the', 'sand', 'endseq'],
#    ['startseq',
#     'three',
#     'little',
#     'blond',
#     'girls',
#     'two',
#     'in',
#     'blue',
#     'one',
#     'in',
#     'pink',
#     'play',
#     'on',
#     'sunny',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'three',
#     'young',
#     'girls',
#     'dance',
#     'on',
#     'the',
#     'beach',
#     'in',
#     'the',
#     'sand',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'is',
#    'jumping',
#    'into',
#    'the',
#    'water',
#    'endseq']),
#  '1258913059_07c613f7ff': ([['startseq',
#     'couple',
#     'of',
#     'people',
#     'sit',
#     'outdoors',
#     'at',
#     'table',
#     'with',
#     'an',
#     'umbrella',
#     'and',
#     'talk',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'are',
#     'sitting',
#     'at',
#     'an',
#     'outside',
#     'picnic',
#     'bench',
#     'with',
#     'an',
#     'umbrella',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'sit',
#     'at',
#     'an',
#     'outdoor',
#     'cafe',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'sit',
#     'at',
#     'an',
#     'outdoor',
#     'table',
#     'in',
#     'front',
#     'of',
#     'building',
#     'painted',
#     'like',
#     'the',
#     'union',
#     'jack',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'sit',
#     'at',
#     'picnic',
#     'table',
#     'outside',
#     'of',
#     'building',
#     'painted',
#     'like',
#     'union',
#     'jack',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1262583859_653f1469a9': ([['startseq',
#     'biker',
#     'enjoys',
#     'coffee',
#     'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'bright',
#     'green',
#     'shirt',
#     'and',
#     'sunglasses',
#     'is',
#     'riding',
#     'bicycle',
#     'through',
#     'the',
#     'streets',
#     'whilst',
#     'drinking',
#     'latte',
#     'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'bright',
#     'green',
#     'shirt',
#     'riding',
#     'bicycle',
#     'in',
#     'paved',
#     'courtyard',
#     'carying',
#     'drink',
#     'endseq'],
#    ['startseq',
#     'man',
#     'rides',
#     'on',
#     'his',
#     'bike',
#     'with',
#     'one',
#     'hand',
#     'and',
#     'holds',
#     'drink',
#     'with',
#     'the',
#     'other',
#     'endseq'],
#    ['startseq',
#     'man',
#     'riding',
#     'bike',
#     'wearing',
#     'green',
#     'shirt',
#     'with',
#     'drink',
#     'in',
#     'his',
#     'hand',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'rock',
#    'with',
#    'his',
#    'bike',
#    'endseq']),
#  '1267711451_e2a754b4f8': ([['startseq',
#     'black',
#     'and',
#     'white',
#     'dog',
#     'carrying',
#     'large',
#     'stick',
#     'endseq'],
#    ['startseq',
#     'black',
#     'and',
#     'white',
#     'dog',
#     'is',
#     'carrying',
#     'stick',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'black',
#     'and',
#     'white',
#     'dog',
#     'walking',
#     'through',
#     'the',
#     'grass',
#     'with',
#     'long',
#     'stick',
#     'in',
#     'his',
#     'mouth',
#     'endseq'],
#    ['startseq', 'dog', 'holds', 'stick', 'in', 'its', 'mouth', 'endseq'],
#    ['startseq',
#     'dog',
#     'trots',
#     'across',
#     'the',
#     'ground',
#     'with',
#     'large',
#     'stick',
#     'in',
#     'his',
#     'mouth',
#     'endseq']],
#   ['startseq',
#    'two',
#    'dogs',
#    'are',
#    'playing',
#    'with',
#    'ball',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '127488876_f2d2a89588': ([['startseq',
#     'one',
#     'man',
#     'in',
#     'red',
#     'shirt',
#     'and',
#     'black',
#     'pants',
#     'with',
#     'man',
#     'in',
#     'white',
#     'shirt',
#     'and',
#     'tan',
#     'shorts',
#     'golfing',
#     'endseq'],
#    ['startseq',
#     'tree',
#     'in',
#     'the',
#     'foreground',
#     'two',
#     'men',
#     'playing',
#     'golf',
#     'in',
#     'the',
#     'background',
#     'endseq'],
#    ['startseq',
#     'two',
#     'golfers',
#     'are',
#     'standing',
#     'on',
#     'the',
#     'fairway',
#     'looking',
#     'off',
#     'into',
#     'the',
#     'distance',
#     'endseq'],
#    ['startseq',
#     'two',
#     'golfers',
#     'look',
#     'off',
#     'into',
#     'the',
#     'distance',
#     'with',
#     'hands',
#     'blocking',
#     'the',
#     'sun',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'looking',
#     'into',
#     'the',
#     'distance',
#     'on',
#     'golf',
#     'course',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '127490019_7c5c08cb11': ([['startseq',
#     'girl',
#     'is',
#     'getting',
#     'ready',
#     'to',
#     'swing',
#     'the',
#     'club',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'in',
#     'shorts',
#     'and',
#     'blue',
#     'sleeveless',
#     'shirt',
#     'leans',
#     'over',
#     'golf',
#     'club',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'is',
#     'taking',
#     'swing',
#     'with',
#     'golf',
#     'club',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'wearing',
#     'blue',
#     'shirt',
#     'and',
#     'hat',
#     'with',
#     'khaki',
#     'shorts',
#     'plays',
#     'golf',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'wearing',
#     'blue',
#     'begins',
#     'golf',
#     'swing',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '1282392036_5a0328eb86': ([['startseq',
#     'group',
#     'of',
#     'people',
#     'in',
#     'costume',
#     'at',
#     'renaissance',
#     'fair',
#     'endseq'],
#    ['startseq',
#     'people',
#     'in',
#     'costume',
#     'at',
#     'renaissance',
#     'fair',
#     'endseq'],
#    ['startseq',
#     'two',
#     'woman',
#     'in',
#     'colorful',
#     'costumes',
#     'look',
#     'at',
#     'little',
#     'girl',
#     'wearing',
#     'brown',
#     'vest',
#     'endseq'],
#    ['startseq',
#     'two',
#     'women',
#     'and',
#     'child',
#     'are',
#     'sitting',
#     'by',
#     'cart',
#     'of',
#     'arrows',
#     'in',
#     'front',
#     'of',
#     'booth',
#     'at',
#     'medieval',
#     'fayre',
#     'endseq'],
#    ['startseq',
#     'two',
#     'women',
#     'crouch',
#     'near',
#     'small',
#     'child',
#     'at',
#     'medieval',
#     'fair',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1287073593_f3d2a62455': ([['startseq',
#     'group',
#     'of',
#     'dogs',
#     'pull',
#     'person',
#     'on',
#     'dog',
#     'sled',
#     'up',
#     'hill',
#     'endseq'],
#    ['startseq',
#     'dogsled',
#     'rider',
#     'pulled',
#     'past',
#     'flags',
#     'on',
#     'snowy',
#     'hill',
#     'endseq'],
#    ['startseq', 'dogs', 'pulling', 'sled', 'in', 'sled', 'race', 'endseq'],
#    ['startseq',
#     'five',
#     'sled',
#     'dogs',
#     'are',
#     'pulling',
#     'person',
#     'on',
#     'sled',
#     'through',
#     'the',
#     'snow',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'is',
#     'mushing',
#     'his',
#     'dogs',
#     'on',
#     'snow',
#     'trail',
#     'endseq']],
#   ['startseq',
#    'two',
#    'dogs',
#    'are',
#    'playing',
#    'with',
#    'red',
#    'ball',
#    'in',
#    'the',
#    'snow',
#    'endseq']),
#  '1287475186_2dee85f1a5': ([['startseq',
#     'boy',
#     'sitting',
#     'in',
#     'water',
#     'endseq'],
#    ['startseq',
#     'small',
#     'boy',
#     'is',
#     'sitting',
#     'in',
#     'the',
#     'water',
#     'and',
#     'water',
#     'is',
#     'splashing',
#     'up',
#     'through',
#     'his',
#     'legs',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'in',
#     'swimming',
#     'suit',
#     'sits',
#     'in',
#     'water',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'sitting',
#     'on',
#     'water',
#     'jet',
#     'in',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'little',
#     'boy',
#     'sitting',
#     'in',
#     'water',
#     'with',
#     'fountain',
#     'coming',
#     'up',
#     'through',
#     'his',
#     'lap',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'pool', 'endseq']),
#  '1298295313_db1f4c6522': ([['startseq',
#     'blonde',
#     'boy',
#     'wearing',
#     'blue',
#     'life',
#     'vest',
#     'and',
#     'camo',
#     'shorts',
#     'jumps',
#     'off',
#     'diveboard',
#     'into',
#     'blue',
#     'lake',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'diving',
#     'backward',
#     'off',
#     'pier',
#     'in',
#     'large',
#     'lake',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'blue',
#     'life',
#     'jacket',
#     'jumps',
#     'into',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'blue',
#     'life',
#     'jacket',
#     'jumps',
#     'off',
#     'board',
#     'into',
#     'the',
#     'lake',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'is',
#     'holding',
#     'his',
#     'nose',
#     'and',
#     'jumping',
#     'off',
#     'diving',
#     'board',
#     'backwards',
#     'into',
#     'lake',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'the', 'water', 'endseq']),
#  '1311388430_4ab0cd1a1f': ([['startseq',
#     'person',
#     'hanging',
#     'from',
#     'telephone',
#     'pole',
#     'near',
#     'the',
#     'mountains',
#     'endseq'],
#    ['startseq',
#     'person',
#     'is',
#     'hanging',
#     'in',
#     'the',
#     'air',
#     'from',
#     'the',
#     'power',
#     'lines',
#     'endseq'],
#    ['startseq',
#     'person',
#     'is',
#     'hanging',
#     'upside',
#     'down',
#     'from',
#     'power',
#     'lines',
#     'endseq'],
#    ['startseq',
#     'person',
#     'hanging',
#     'upside',
#     'down',
#     'from',
#     'poles',
#     'endseq'],
#    ['startseq',
#     'someone',
#     'is',
#     'suspended',
#     'from',
#     'electrical',
#     'wires',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'rock',
#    'overlooking',
#    'the',
#    'ocean',
#    'endseq']),
#  '1317292658_ba29330a0b': ([['startseq',
#     'boy',
#     'enjoys',
#     'rain',
#     'shower',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'bathing',
#     'trunks',
#     'is',
#     'standing',
#     'under',
#     'water',
#     'shower',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'swim',
#     'trunks',
#     'screams',
#     'while',
#     'being',
#     'sprayed',
#     'with',
#     'water',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'is',
#     'squinting',
#     'while',
#     'being',
#     'sprayed',
#     'with',
#     'water',
#     'from',
#     'flat',
#     'ground',
#     'surface',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'wearing',
#     'black',
#     'swimming',
#     'trunks',
#     'is',
#     'standing',
#     'in',
#     'fountain',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'the', 'water', 'endseq']),
#  '1322323208_c7ecb742c6': ([['startseq',
#     'boy',
#     'and',
#     'girl',
#     'playing',
#     'on',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'small',
#     'boy',
#     'and',
#     'girls',
#     'are',
#     'playing',
#     'in',
#     'the',
#     'sand',
#     'on',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'one',
#     'of',
#     'which',
#     'is',
#     'holding',
#     'stick',
#     'are',
#     'standing',
#     'on',
#     'the',
#     'beach',
#     'as',
#     'the',
#     'sun',
#     'begins',
#     'to',
#     'set',
#     'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'on',
#     'the',
#     'beach',
#     'silhouetted',
#     'by',
#     'the',
#     'setting',
#     'sun',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'children',
#     'playing',
#     'with',
#     'sticks',
#     'at',
#     'the',
#     'beach',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'with',
#    'red',
#    'ball',
#    'endseq']),
#  '132489044_3be606baf7': ([['startseq',
#     'man',
#     'sleeping',
#     'with',
#     'bag',
#     'on',
#     'his',
#     'lap',
#     'on',
#     'public',
#     'transportation',
#     'endseq'],
#    ['startseq',
#     'man',
#     'who',
#     'has',
#     'fallen',
#     'asleep',
#     'on',
#     'public',
#     'transportation',
#     'endseq'],
#    ['startseq',
#     'an',
#     'asian',
#     'man',
#     'in',
#     'suit',
#     'on',
#     'the',
#     'subway',
#     'asleep',
#     'endseq'],
#    ['startseq',
#     'tired',
#     'business',
#     'man',
#     'takes',
#     'quick',
#     'nap',
#     'while',
#     'riding',
#     'the',
#     'train',
#     'endseq'],
#    ['startseq',
#     'young',
#     'man',
#     'in',
#     'suit',
#     'and',
#     'tie',
#     'leans',
#     'against',
#     'railing',
#     'to',
#     'take',
#     'nap',
#     'on',
#     'public',
#     'transit',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1329832826_432538d331': ([['startseq',
#     'people',
#     'stand',
#     'on',
#     'street',
#     'corner',
#     'at',
#     'dusk',
#     'with',
#     'pharmacy',
#     'in',
#     'the',
#     'background',
#     'endseq'],
#    ['startseq',
#     'people',
#     'stand',
#     'outside',
#     'of',
#     'the',
#     'rite',
#     'aid',
#     'pharmacy',
#     'on',
#     'broadway',
#     'endseq'],
#    ['startseq',
#     'people',
#     'waiting',
#     'to',
#     'cross',
#     'the',
#     'street',
#     'in',
#     'front',
#     'of',
#     'pharmacy',
#     'with',
#     'lit',
#     'up',
#     'sign',
#     'endseq'],
#    ['startseq',
#     'some',
#     'people',
#     'look',
#     'to',
#     'cross',
#     'the',
#     'street',
#     'in',
#     'front',
#     'of',
#     'drug',
#     'store',
#     'endseq'],
#    ['startseq',
#     'this',
#     'is',
#     'picture',
#     'of',
#     'broadway',
#     'rite',
#     'aid',
#     'pharmacy',
#     'that',
#     'has',
#     'bright',
#     'neon',
#     'sign',
#     'and',
#     'people',
#     'are',
#     'prepared',
#     'to',
#     'cross',
#     'the',
#     'street',
#     'in',
#     'front',
#     'of',
#     'it',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'with',
#    'his',
#    'head',
#    'endseq']),
#  '1332722096_1e3de8ae70': ([['startseq',
#     'three',
#     'women',
#     'standing',
#     'on',
#     'city',
#     'street',
#     'endseq'],
#    ['startseq', 'three', 'women', 'walk', 'down', 'the', 'street', 'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'and',
#     'woman',
#     'walking',
#     'on',
#     'the',
#     'sidewalk',
#     'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'in',
#     'bright',
#     'green',
#     'boots',
#     'and',
#     'woman',
#     'are',
#     'together',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'ladies',
#     'in',
#     'green',
#     'boots',
#     'are',
#     'walking',
#     'through',
#     'an',
#     'urban',
#     'area',
#     'while',
#     'an',
#     'older',
#     'lady',
#     'wearing',
#     'black',
#     'shoes',
#     'follows',
#     'them',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1339596997_8ac29c1841': ([['startseq',
#     'three',
#     'females',
#     'wearing',
#     'head',
#     'scarves',
#     'standing',
#     'together',
#     'endseq'],
#    ['startseq',
#     'three',
#     'muslim',
#     'women',
#     'are',
#     'looking',
#     'at',
#     'camera',
#     'endseq'],
#    ['startseq',
#     'three',
#     'women',
#     'in',
#     'dresses',
#     'and',
#     'head',
#     'scarves',
#     'outside',
#     'endseq'],
#    ['startseq',
#     'three',
#     'women',
#     'in',
#     'head',
#     'scarves',
#     'examine',
#     'camera',
#     'endseq'],
#    ['startseq',
#     'three',
#     'women',
#     'with',
#     'head',
#     'scarves',
#     'and',
#     'long',
#     'skirts',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1343426964_cde3fb54e8': ([['startseq',
#     'blond',
#     'boy',
#     'in',
#     'blue',
#     'tee',
#     'shirts',
#     'stands',
#     'smiling',
#     'before',
#     'craft',
#     'of',
#     'green',
#     'nylon',
#     'fabric',
#     'endseq'],
#    ['startseq',
#     'child',
#     'poses',
#     'wearing',
#     'glasses',
#     'near',
#     'water',
#     'outside',
#     'endseq'],
#    ['startseq', 'small', 'girl', 'smiling', 'on', 'the', 'beach', 'endseq'],
#    ['startseq', 'young', 'kid', 'at', 'the', 'beach', 'endseq'],
#    ['startseq',
#     'young',
#     'man',
#     'wearing',
#     'swimming',
#     'goggles',
#     'wearing',
#     'blue',
#     'shirt',
#     'with',
#     'pirate',
#     'skull',
#     'on',
#     'it',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '1348304997_afe60a61df': ([['startseq',
#     'barefoot',
#     'redheaded',
#     'girl',
#     'jumping',
#     'over',
#     'rail',
#     'endseq'],
#    ['startseq', 'girl', 'jumps', 'on', 'the', 'trampoline', 'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'jumping',
#     'over',
#     'railing',
#     'or',
#     'ladder',
#     'on',
#     'its',
#     'side',
#     'endseq'],
#    ['startseq',
#     'the',
#     'small',
#     'red',
#     'haired',
#     'girl',
#     'jumps',
#     'on',
#     'the',
#     'trampoline',
#     'under',
#     'the',
#     'tree',
#     'by',
#     'the',
#     'shed',
#     'endseq'],
#    ['startseq',
#     'the',
#     'young',
#     'child',
#     'with',
#     'red',
#     'hair',
#     'bounced',
#     'on',
#     'the',
#     'trampoline',
#     'endseq']],
#   ['startseq',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'with',
#    'his',
#    'arms',
#    'in',
#    'the',
#    'air',
#    'endseq']),
#  '1352410176_af6b139734': ([['startseq',
#     'blonde',
#     'girl',
#     'is',
#     'stepping',
#     'on',
#     'vertical',
#     'logs',
#     'in',
#     'the',
#     'sand',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'is',
#     'walking',
#     'along',
#     'line',
#     'of',
#     'logs',
#     'on',
#     'sandy',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'balances',
#     'on',
#     'wooden',
#     'pylons',
#     'at',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'is',
#     'walking',
#     'on',
#     'stumps',
#     'on',
#     'the',
#     'beach',
#     'next',
#     'to',
#     'the',
#     'ocean',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'walking',
#     'along',
#     'the',
#     'tops',
#     'of',
#     'wooden',
#     'posts',
#     'set',
#     'into',
#     'sand',
#     'on',
#     'beach',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'rock',
#    'overlooking',
#    'the',
#    'water',
#    'endseq']),
#  '1356796100_b265479721': ([['startseq',
#     'girl',
#     'in',
#     'flowered',
#     'dress',
#     'peaking',
#     'through',
#     'some',
#     'leaves',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'peeks',
#     'through',
#     'the',
#     'leaves',
#     'on',
#     'tree',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'peeks',
#     'through',
#     'the',
#     'green',
#     'leaves',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'peers',
#     'through',
#     'the',
#     'green',
#     'foliage',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'face',
#     'looking',
#     'through',
#     'leaves',
#     'endseq']],
#   ['startseq',
#    'two',
#    'girls',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '136552115_6dc3e7231c': ([['startseq',
#     'helmeted',
#     'man',
#     'jumping',
#     'off',
#     'rock',
#     'on',
#     'mountain',
#     'bike',
#     'endseq'],
#    ['startseq',
#     'man',
#     'jumping',
#     'on',
#     'his',
#     'bmx',
#     'with',
#     'another',
#     'bmxer',
#     'watching',
#     'endseq'],
#    ['startseq',
#     'mountain',
#     'biker',
#     'is',
#     'jumping',
#     'his',
#     'bike',
#     'over',
#     'rock',
#     'as',
#     'another',
#     'cyclist',
#     'stands',
#     'on',
#     'the',
#     'trail',
#     'watching',
#     'endseq'],
#    ['startseq',
#     'person',
#     'taking',
#     'jump',
#     'off',
#     'rock',
#     'on',
#     'dirt',
#     'bike',
#     'endseq'],
#    ['startseq', 'the', 'bike', 'rider', 'jumps', 'off', 'rock', 'endseq']],
#   ['startseq', 'man', 'rides', 'bike', 'on', 'dirt', 'trail', 'endseq']),
#  '136644343_0e2b423829': ([['startseq',
#     'boy',
#     'rides',
#     'on',
#     'tire',
#     'swing',
#     'endseq'],
#    ['startseq', 'boy', 'swinging', 'on', 'tireswing', 'endseq'],
#    ['startseq', 'small', 'boy', 'in', 'horizontal', 'tire', 'swing', 'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'smiles',
#     'at',
#     'the',
#     'camera',
#     'from',
#     'the',
#     'tire',
#     'swing',
#     'endseq'],
#    ['startseq', 'young', 'boy', 'swinging', 'on', 'tire', 'swing', 'endseq']],
#   ['startseq', 'boy', 'is', 'swinging', 'on', 'swing', 'endseq']),
#  '136886677_6026c622eb': ([['startseq',
#     'large',
#     'man',
#     'sits',
#     'in',
#     'the',
#     'back',
#     'of',
#     'canoe',
#     'with',
#     'another',
#     'man',
#     'in',
#     'front',
#     'on',
#     'river',
#     'endseq'],
#    ['startseq',
#     'two',
#     'man',
#     'are',
#     'paddling',
#     'kayak',
#     'along',
#     'river',
#     'with',
#     'green',
#     'trees',
#     'on',
#     'either',
#     'side',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'in',
#     'small',
#     'boat',
#     'rowing',
#     'down',
#     'river',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'paddling',
#     'canoe',
#     'down',
#     'narrow',
#     'stream',
#     'endseq'],
#    ['startseq',
#     'two',
#     'paddlers',
#     'propel',
#     'canoe',
#     'down',
#     'treelined',
#     'stream',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'walking',
#    'through',
#    'the',
#    'water',
#    'endseq']),
#  '1386964743_9e80d96b05': ([['startseq',
#     'boy',
#     'is',
#     'playing',
#     'with',
#     'camera',
#     'whilst',
#     'standing',
#     'on',
#     'dirt',
#     'track',
#     'endseq'],
#    ['startseq', 'child', 'in', 'field', 'endseq'],
#    ['startseq',
#     'kid',
#     'standing',
#     'in',
#     'the',
#     'middle',
#     'of',
#     'dirt',
#     'road',
#     'endseq'],
#    ['startseq',
#     'young',
#     'child',
#     'stands',
#     'in',
#     'path',
#     'in',
#     'field',
#     'of',
#     'sunflowers',
#     'endseq'],
#    ['startseq',
#     'small',
#     'child',
#     'with',
#     'black',
#     'hair',
#     'standing',
#     'in',
#     'car',
#     'track',
#     'near',
#     'sunflowers',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'with',
#    'his',
#    'arms',
#    'in',
#    'the',
#    'air',
#    'endseq']),
#  '138718600_f430ebca17': ([['startseq',
#     'two',
#     'bicycles',
#     'are',
#     'standing',
#     'behind',
#     'two',
#     'people',
#     'sitting',
#     'on',
#     'the',
#     'grass',
#     'near',
#     'body',
#     'of',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'blonde',
#     'women',
#     'sit',
#     'beside',
#     'their',
#     'bicycles',
#     'in',
#     'the',
#     'grass',
#     'beside',
#     'body',
#     'of',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'are',
#     'sitting',
#     'on',
#     'path',
#     'by',
#     'river',
#     'with',
#     'their',
#     'bicycles',
#     'parked',
#     'beside',
#     'them',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'are',
#     'sitting',
#     'by',
#     'pond',
#     'next',
#     'to',
#     'their',
#     'bikes',
#     'endseq'],
#    ['startseq',
#     'two',
#     'women',
#     'sitting',
#     'in',
#     'the',
#     'grass',
#     'with',
#     'their',
#     'bikes',
#     'behind',
#     'them',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'helmet',
#    'is',
#    'riding',
#    'bike',
#    'on',
#    'dirt',
#    'path',
#    'endseq']),
#  '1387785218_cee67735f5': ([['startseq',
#     'child',
#     'pushes',
#     'doll',
#     'in',
#     'baby',
#     'carriage',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'pushing',
#     'baby',
#     'doll',
#     'stroller',
#     'endseq'],
#    ['startseq',
#     'little',
#     'kid',
#     'in',
#     'blue',
#     'shoes',
#     'is',
#     'pushing',
#     'toy',
#     'baby',
#     'in',
#     'stroller',
#     'endseq'],
#    ['startseq',
#     'small',
#     'child',
#     'pushes',
#     'stroller',
#     'down',
#     'the',
#     'street',
#     'endseq'],
#    ['startseq',
#     'young',
#     'child',
#     'carrying',
#     'doll',
#     'in',
#     'stroller',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '1389264266_8170bc1c54': ([['startseq',
#     'girl',
#     'with',
#     'pink',
#     'streaked',
#     'hair',
#     'and',
#     'fur',
#     'uggs',
#     'looks',
#     'back',
#     'while',
#     'the',
#     'girl',
#     'walking',
#     'next',
#     'to',
#     'her',
#     'looks',
#     'at',
#     'her',
#     'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'facing',
#     'each',
#     'other',
#     'one',
#     'has',
#     'skull',
#     'face',
#     'bag',
#     'wearing',
#     'red',
#     'and',
#     'black',
#     'shirt',
#     'the',
#     'other',
#     'is',
#     'wearing',
#     'beaded',
#     'belt',
#     'endseq'],
#    ['startseq', 'two', 'girls', 'walking', 'down', 'the', 'street', 'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'wearing',
#     'goth',
#     'trendy',
#     'clothing',
#     'while',
#     'one',
#     'looks',
#     'back',
#     'at',
#     'the',
#     'camera',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'girls',
#     'wearing',
#     'goth',
#     'clothes',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1392272228_cf104086e6': ([['startseq',
#     'black',
#     'dog',
#     'carrying',
#     'an',
#     'object',
#     'out',
#     'of',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'carrying',
#     'some',
#     'seaweed',
#     'out',
#     'of',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'is',
#     'coming',
#     'out',
#     'of',
#     'the',
#     'ocean',
#     'water',
#     'on',
#     'the',
#     'beach',
#     'with',
#     'something',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'with',
#     'stick',
#     'in',
#     'its',
#     'mouth',
#     'is',
#     'walking',
#     'out',
#     'of',
#     'the',
#     'water',
#     'onto',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'retrieves',
#     'branch',
#     'from',
#     'on',
#     'beach',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'water', 'endseq']),
#  '1394368714_3bc7c19969': ([['startseq',
#     'dog',
#     'waits',
#     'as',
#     'his',
#     'owner',
#     'rummages',
#     'through',
#     'collection',
#     'of',
#     'stuff',
#     'endseq'],
#    ['startseq',
#     'man',
#     'holding',
#     'the',
#     'leash',
#     'of',
#     'pug',
#     'bends',
#     'down',
#     'to',
#     'look',
#     'in',
#     'bin',
#     'at',
#     'an',
#     'outdoor',
#     'rummage',
#     'sale',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'pug',
#     'dog',
#     'bends',
#     'over',
#     'to',
#     'pick',
#     'something',
#     'off',
#     'the',
#     'sidewalk',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'pug',
#     'on',
#     'leash',
#     'bending',
#     'down',
#     'to',
#     'examine',
#     'merchandise',
#     'endseq'],
#    ['startseq',
#     'person',
#     'holding',
#     'small',
#     'dog',
#     'on',
#     'leash',
#     'is',
#     'bending',
#     'over',
#     'and',
#     'looking',
#     'through',
#     'items',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'with',
#    'his',
#    'head',
#    'endseq']),
#  '1402640441_81978e32a9': ([['startseq',
#     'boy',
#     'in',
#     'red',
#     'and',
#     'blue',
#     'shorts',
#     'is',
#     'trying',
#     'to',
#     'catch',
#     'soccer',
#     'ball',
#     'while',
#     'running',
#     'in',
#     'sand',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'wearing',
#     'red',
#     'bathing',
#     'suit',
#     'reaches',
#     'for',
#     'soccer',
#     'ball',
#     'endseq'],
#    ['startseq', 'kid', 'guards', 'face', 'from', 'soccer', 'ball', 'endseq'],
#    ['startseq',
#     'the',
#     'little',
#     'boy',
#     'in',
#     'red',
#     'trunks',
#     'is',
#     'attempting',
#     'to',
#     'catch',
#     'soccer',
#     'ball',
#     'that',
#     'is',
#     'coming',
#     'towards',
#     'him',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'plays',
#     'ball',
#     'on',
#     'the',
#     'beach',
#     'endseq']],
#   ['startseq', 'two', 'boys', 'playing', 'soccer', 'on', 'field', 'endseq']),
#  '1404832008_68e432665b': ([['startseq',
#     'man',
#     'in',
#     'harness',
#     'being',
#     'dragged',
#     'across',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'harness',
#     'lands',
#     'in',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'man',
#     'on',
#     'tag',
#     'line',
#     'going',
#     'into',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'man',
#     'on',
#     'zip',
#     'line',
#     'being',
#     'propelled',
#     'through',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'man',
#     'wearing',
#     'bathing',
#     'trunks',
#     'is',
#     'parasailing',
#     'in',
#     'the',
#     'water',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'the', 'water', 'endseq']),
#  '1408958345_68eea9a4e4': ([['startseq',
#     'girl',
#     'smiles',
#     'as',
#     'she',
#     'runs',
#     'across',
#     'the',
#     'white',
#     'sandy',
#     'beach',
#     'in',
#     'her',
#     'swimsuit',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'in',
#     'flowered',
#     'bathingsuit',
#     'runs',
#     'through',
#     'the',
#     'sand',
#     'at',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'in',
#     'flower',
#     'swimsuit',
#     'running',
#     'across',
#     'the',
#     'beach',
#     'with',
#     'waves',
#     'in',
#     'the',
#     'background',
#     'endseq'],
#    ['startseq',
#     'there',
#     'is',
#     'little',
#     'girl',
#     'running',
#     'on',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'the',
#     'young',
#     'girl',
#     'is',
#     'running',
#     'on',
#     'sandy',
#     'beach',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'pool', 'endseq']),
#  '1415591512_a84644750c': ([['startseq',
#     'girl',
#     'in',
#     'boots',
#     'is',
#     'active',
#     'in',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'is',
#     'playing',
#     'in',
#     'the',
#     'mud',
#     'near',
#     'car',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'in',
#     'front',
#     'of',
#     'silver',
#     'car',
#     'wearing',
#     'boots',
#     'demonstrates',
#     'some',
#     'interesting',
#     'moves',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'moving',
#     'quickly',
#     'on',
#     'grass',
#     'beside',
#     'silver',
#     'car',
#     'endseq'],
#    ['startseq',
#     'the',
#     'little',
#     'girl',
#     'is',
#     'spinning',
#     'around',
#     'making',
#     'her',
#     'hair',
#     'fly',
#     'in',
#     'front',
#     'of',
#     'the',
#     'silver',
#     'car',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'with',
#    'her',
#    'arms',
#    'endseq']),
#  '1417031097_ab656bc4bd': ([['startseq',
#     'person',
#     'is',
#     'laughing',
#     'on',
#     'roller',
#     'coaster',
#     'ride',
#     'endseq'],
#    ['startseq',
#     'photo',
#     'of',
#     'ride',
#     'at',
#     'an',
#     'amusement',
#     'park',
#     'on',
#     'an',
#     'overcast',
#     'day',
#     'endseq'],
#    ['startseq',
#     'people',
#     'are',
#     'in',
#     'ride',
#     'that',
#     'drops',
#     'you',
#     'from',
#     'great',
#     'height',
#     'endseq'],
#    ['startseq', 'people', 'on', 'an', 'amusement', 'park', 'ride', 'endseq'],
#    ['startseq', 'people', 'on', 'ride', 'at', 'fair', 'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
# ...
#     'while',
#     'riding',
#     'above',
#     'the',
#     'fair',
#     'endseq'],
#    ['startseq',
#     'the',
#     'woman',
#     'is',
#     'wearing',
#     'an',
#     'orange',
#     'dress',
#     'riding',
#     'on',
#     'the',
#     'ferris',
#     'wheel',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '771048251_602e5e8f45': ([['startseq',
#     'blonde',
#     'child',
#     'is',
#     'being',
#     'bitten',
#     'on',
#     'the',
#     'nose',
#     'by',
#     'little',
#     'orange',
#     'kitten',
#     'endseq'],
#    ['startseq', 'cat', 'bites', 'human', 'nose', 'endseq'],
#    ['startseq',
#     'an',
#     'orange',
#     'striped',
#     'kitten',
#     'is',
#     'biting',
#     'girl',
#     'on',
#     'the',
#     'nose',
#     'endseq'],
#    ['startseq',
#     'orange',
#     'kitten',
#     'biting',
#     'the',
#     'nose',
#     'of',
#     'child',
#     'endseq'],
#    ['startseq',
#     'orange',
#     'striped',
#     'kitten',
#     'biting',
#     'blonde',
#     'girl',
#     'on',
#     'the',
#     'nose',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'with',
#    'his',
#    'arms',
#    'in',
#    'the',
#    'air',
#    'endseq']),
#  '791338571_7f38510bf7': ([['startseq',
#     'bull',
#     'stands',
#     'in',
#     'field',
#     'next',
#     'to',
#     'red',
#     'car',
#     'endseq'],
#    ['startseq',
#     'red',
#     'car',
#     'is',
#     'parked',
#     'next',
#     'to',
#     'black',
#     'bull',
#     'in',
#     'grassy',
#     'field',
#     'endseq'],
#    ['startseq',
#     'red',
#     'car',
#     'parked',
#     'next',
#     'to',
#     'cow',
#     'in',
#     'field',
#     'endseq'],
#    ['startseq',
#     'large',
#     'black',
#     'animal',
#     'is',
#     'as',
#     'large',
#     'as',
#     'small',
#     'red',
#     'car',
#     'endseq'],
#    ['startseq',
#     'there',
#     'is',
#     'small',
#     'red',
#     'car',
#     'with',
#     'black',
#     'bull',
#     'standing',
#     'beside',
#     'it',
#     'in',
#     'the',
#     'middle',
#     'of',
#     'field',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'white',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'grass',
#    'with',
#    'his',
#    'head',
#    'in',
#    'the',
#    'background',
#    'endseq']),
#  '799486353_f665d7b0f0': ([['startseq',
#     'child',
#     'is',
#     'waiting',
#     'on',
#     'the',
#     'beach',
#     'holding',
#     'boogie',
#     'board',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'looks',
#     'out',
#     'into',
#     'the',
#     'ocean',
#     'as',
#     'she',
#     'stands',
#     'on',
#     'the',
#     'sand',
#     'with',
#     'her',
#     'yellow',
#     'boogie',
#     'board',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'holding',
#     'boogie',
#     'board',
#     'at',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'standing',
#     'on',
#     'the',
#     'beach',
#     'with',
#     'her',
#     'body',
#     'board',
#     'looks',
#     'out',
#     'on',
#     'the',
#     'ocean',
#     'endseq'],
#    ['startseq',
#     'young',
#     'woman',
#     'holding',
#     'surfboard',
#     'contemplates',
#     'the',
#     'ocean',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'the', 'water', 'endseq']),
#  '801607443_f15956d1ce': ([['startseq',
#     'one',
#     'climber',
#     'is',
#     'sitting',
#     'on',
#     'the',
#     'rock',
#     'overlooking',
#     'the',
#     'ocean',
#     'whilst',
#     'another',
#     'climber',
#     'is',
#     'on',
#     'her',
#     'way',
#     'up',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'are',
#     'on',
#     'rock',
#     'overlooking',
#     'the',
#     'ocean',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'climb',
#     'rock',
#     'overhanging',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'climb',
#     'rocks',
#     'over',
#     'some',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'rock',
#     'climbing',
#     'near',
#     'water',
#     'endseq']],
#   ['startseq',
#    'man',
#    'is',
#    'standing',
#    'on',
#    'rock',
#    'overlooking',
#    'the',
#    'ocean',
#    'endseq']),
#  '820169182_f5e78d7d19': ([['startseq',
#     'two',
#     'babies',
#     'look',
#     'up',
#     'while',
#     'they',
#     'are',
#     'playing',
#     'in',
#     'playpen',
#     'with',
#     'lot',
#     'of',
#     'balls',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'in',
#     'tentlike',
#     'area',
#     'with',
#     'colorful',
#     'balls',
#     'on',
#     'floor',
#     'endseq'],
#    ['startseq', 'two', 'children', 'look', 'up', 'endseq'],
#    ['startseq',
#     'two',
#     'kids',
#     'are',
#     'in',
#     'pen',
#     'playing',
#     'with',
#     'colorful',
#     'balls',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'children',
#     'play',
#     'with',
#     'colored',
#     'balls',
#     'endseq']],
#   ['startseq',
#    'little',
#    'boy',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '86412576_c53392ef80': ([['startseq',
#     'group',
#     'of',
#     'people',
#     'are',
#     'walking',
#     'while',
#     'holding',
#     'numerous',
#     'baskets',
#     'and',
#     'rugs',
#     'endseq'],
#    ['startseq',
#     'man',
#     'carrying',
#     'many',
#     'woven',
#     'baskets',
#     'next',
#     'to',
#     'man',
#     'carrying',
#     'stack',
#     'of',
#     'rugs',
#     'on',
#     'his',
#     'back',
#     'endseq'],
#    ['startseq',
#     'two',
#     'individuals',
#     'carrying',
#     'numerous',
#     'products',
#     'to',
#     'sell',
#     'are',
#     'walking',
#     'on',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'carrying',
#     'colorful',
#     'baskets',
#     'and',
#     'blankets',
#     'walk',
#     'near',
#     'building',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'walking',
#     'laden',
#     'down',
#     'with',
#     'baskets',
#     'and',
#     'blankets',
#     'endseq']],
#   ['startseq',
#    'two',
#    'people',
#    'are',
#    'playing',
#    'with',
#    'their',
#    'heads',
#    'endseq']),
#  '872622575_ba1d3632cc': ([['startseq',
#     'man',
#     'climbing',
#     'mountain',
#     'endseq'],
#    ['startseq', 'man', 'climbs', 'mountain', 'endseq'],
#    ['startseq',
#     'man',
#     'is',
#     'climbing',
#     'the',
#     'side',
#     'of',
#     'mountain',
#     'endseq'],
#    ['startseq',
#     'shirtless',
#     'man',
#     'climbs',
#     'up',
#     'steep',
#     'mountain',
#     'endseq'],
#    ['startseq',
#     'young',
#     'white',
#     'man',
#     'is',
#     'climbing',
#     'mountain',
#     'with',
#     'rope',
#     'as',
#     'guide',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'climbing',
#    'up',
#    'rock',
#    'endseq']),
#  '880220939_0ef1c37f1f': ([['startseq',
#     'group',
#     'of',
#     'woman',
#     'in',
#     'pink',
#     'dresses',
#     'walking',
#     'across',
#     'crosswalk',
#     'towards',
#     'cruisship',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'women',
#     'in',
#     'pink',
#     'dresses',
#     'walking',
#     'across',
#     'street',
#     'endseq'],
#    ['startseq',
#     'girls',
#     'in',
#     'pink',
#     'dresses',
#     'walk',
#     'toward',
#     'cruise',
#     'ship',
#     'endseq'],
#    ['startseq',
#     'ladies',
#     'in',
#     'bright',
#     'dresses',
#     'are',
#     'crossing',
#     'the',
#     'road',
#     'endseq'],
#    ['startseq',
#     'several',
#     'woman',
#     'walking',
#     'down',
#     'the',
#     'street',
#     'dressed',
#     'in',
#     'pink',
#     'and',
#     'other',
#     'assorted',
#     'people',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '888425986_e4b6c12324': ([['startseq',
#     'boy',
#     'is',
#     'upside',
#     'down',
#     'in',
#     'midair',
#     'near',
#     'lake',
#     'at',
#     'sunset',
#     'endseq'],
#    ['startseq',
#     'person',
#     'does',
#     'flip',
#     'by',
#     'two',
#     'sailboats',
#     'and',
#     'lake',
#     'endseq'],
#    ['startseq', 'person', 'flipping', 'upside', 'down', 'endseq'],
#    ['startseq', 'person', 'in', 'midair', 'doing', 'back', 'flip', 'endseq'],
#    ['startseq',
#     'person',
#     'is',
#     'doing',
#     'flip',
#     'in',
#     'midair',
#     'near',
#     'lake',
#     'with',
#     'sails',
#     'behind',
#     'him',
#     'endseq']],
#   ['startseq', 'boy', 'is', 'jumping', 'into', 'the', 'air', 'endseq']),
#  '909191414_1cf5d85821': ([['startseq',
#     'boy',
#     'is',
#     'leaping',
#     'over',
#     'blue',
#     'hose',
#     'pipe',
#     'as',
#     'little',
#     'girl',
#     'watches',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'is',
#     'leaping',
#     'while',
#     'his',
#     'sister',
#     'plays',
#     'around',
#     'hose',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'jumping',
#     'in',
#     'front',
#     'of',
#     'young',
#     'girl',
#     'and',
#     'house',
#     'endseq'],
#    ['startseq',
#     'children',
#     'are',
#     'playing',
#     'in',
#     'and',
#     'around',
#     'garden',
#     'tube',
#     'in',
#     'the',
#     'front',
#     'yard',
#     'of',
#     'house',
#     'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'playing',
#     'above',
#     'blue',
#     'water',
#     'hose',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'grass',
#    'endseq']),
#  '909808296_23c427022d': ([['startseq',
#     'brown',
#     'and',
#     'black',
#     'dog',
#     'on',
#     'leash',
#     'is',
#     'sniffed',
#     'by',
#     'black',
#     'and',
#     'white',
#     'dog',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'on',
#     'leash',
#     'walks',
#     'on',
#     'the',
#     'sidewalk',
#     'while',
#     'another',
#     'dog',
#     'follows',
#     'endseq'],
#    ['startseq',
#     'small',
#     'dog',
#     'on',
#     'leash',
#     'is',
#     'being',
#     'smelled',
#     'by',
#     'another',
#     'animal',
#     'endseq'],
#    ['startseq',
#     'the',
#     'black',
#     'and',
#     'white',
#     'dog',
#     'is',
#     'sniffing',
#     'the',
#     'butt',
#     'of',
#     'the',
#     'brown',
#     'dog',
#     'that',
#     'is',
#     'on',
#     'leash',
#     'endseq'],
#    ['startseq',
#     'two',
#     'small',
#     'dogs',
#     'one',
#     'blackandwhite',
#     'and',
#     'one',
#     'brownandblack',
#     'walk',
#     'down',
#     'the',
#     'street',
#     'endseq']],
#   ['startseq',
#    'two',
#    'dogs',
#    'are',
#    'playing',
#    'with',
#    'ball',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '917574521_74fab68514': ([['startseq',
#     'one',
#     'young',
#     'girl',
#     'pushing',
#     'toy',
#     'while',
#     'her',
#     'twin',
#     'sister',
#     'looks',
#     'on',
#     'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'wearing',
#     'bright',
#     'pink',
#     'clothes',
#     'are',
#     'playing',
#     'with',
#     'toy',
#     'lawnmower',
#     'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'are',
#     'dressed',
#     'the',
#     'same',
#     'and',
#     'one',
#     'of',
#     'them',
#     'is',
#     'playing',
#     'with',
#     'toy',
#     'lawnmower',
#     'endseq'],
#    ['startseq',
#     'two',
#     'little',
#     'girls',
#     'stand',
#     'against',
#     'wall',
#     'one',
#     'girl',
#     'has',
#     'happy',
#     'face',
#     'and',
#     'the',
#     'other',
#     'girl',
#     'has',
#     'sad',
#     'face',
#     'endseq'],
#    ['startseq',
#     'two',
#     'twin',
#     'girls',
#     'playing',
#     'with',
#     'toy',
#     'in',
#     'the',
#     'driveway',
#     'endseq']],
#   ['startseq',
#    'little',
#    'boy',
#    'is',
#    'playing',
#    'on',
#    'the',
#    'swing',
#    'endseq']),
#  '925491651_57df3a5b36': ([['startseq',
#     'dog',
#     'leaps',
#     'out',
#     'of',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq', 'small', 'dog', 'jumping', 'threw', 'some', 'lake', 'endseq'],
#    ['startseq', 'tan', 'dog', 'jumps', 'into', 'water', 'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'is',
#     'splashing',
#     'through',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'jumping',
#     'out',
#     'of',
#     'water',
#     'in',
#     'lake',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'water', 'endseq']),
#  '929679367_ff8c7df2ee': ([['startseq',
#     'beagle',
#     'is',
#     'playing',
#     'with',
#     'tennis',
#     'ball',
#     'endseq'],
#    ['startseq',
#     'puppy',
#     'dog',
#     'is',
#     'playing',
#     'with',
#     'tennis',
#     'ball',
#     'endseq'],
#    ['startseq',
#     'puppy',
#     'is',
#     'playing',
#     'with',
#     'tennis',
#     'ball',
#     'on',
#     'wellkept',
#     'path',
#     'lined',
#     'with',
#     'groomed',
#     'bushes',
#     'endseq'],
#    ['startseq',
#     'puppy',
#     'plays',
#     'with',
#     'tennis',
#     'ball',
#     'on',
#     'stone',
#     'path',
#     'endseq'],
#    ['startseq',
#     'whitefooted',
#     'beagle',
#     'plays',
#     'with',
#     'tennis',
#     'ball',
#     'on',
#     'garden',
#     'path',
#     'endseq']],
#   ['startseq',
#    'two',
#    'dogs',
#    'are',
#    'playing',
#    'with',
#    'ball',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '96420612_feb18fc6c6': ([['startseq',
#     'man',
#     'in',
#     'red',
#     'swim',
#     'trunks',
#     'is',
#     'jumping',
#     'onto',
#     'bodyboard',
#     'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'red',
#     'trunks',
#     'flies',
#     'through',
#     'the',
#     'air',
#     'with',
#     'boogie',
#     'board',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'wakeboard',
#     'is',
#     'diving',
#     'over',
#     'surface',
#     'that',
#     'is',
#     'not',
#     'water',
#     'endseq'],
#    ['startseq', 'shirtless', 'man', 'bodysurfs', 'endseq'],
#    ['startseq', 'man', 'is', 'diving', 'onto', 'his', 'wakeboard', 'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'edge',
#    'of',
#    'the',
#    'water',
#    'endseq']),
#  '968081289_cdba83ce2e': ([['startseq',
#     'boy',
#     'jumping',
#     'off',
#     'of',
#     'dock',
#     'while',
#     'his',
#     'friend',
#     'watches',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'are',
#     'climbing',
#     'wooden',
#     'platform',
#     'and',
#     'jumping',
#     'into',
#     'river',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'jumping',
#     'off',
#     'the',
#     'pier',
#     'into',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'preparing',
#     'to',
#     'jump',
#     'off',
#     'pier',
#     'located',
#     'on',
#     'large',
#     'body',
#     'of',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'jump',
#     'off',
#     'the',
#     'dock',
#     'into',
#     'the',
#     'lake',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '979383193_0a542a059d': ([['startseq',
#     'group',
#     'of',
#     'six',
#     'children',
#     'sit',
#     'at',
#     'wooden',
#     'table',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'young',
#     'asian',
#     'children',
#     'pose',
#     'for',
#     'picture',
#     'at',
#     'table',
#     'endseq'],
#    ['startseq',
#     'six',
#     'children',
#     'all',
#     'with',
#     'black',
#     'hair',
#     'sit',
#     'at',
#     'table',
#     'for',
#     'picture',
#     'endseq'],
#    ['startseq', 'six', 'children', 'at', 'table', 'endseq'],
#    ['startseq',
#     'six',
#     'small',
#     'children',
#     'sitting',
#     'at',
#     'desk',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '997722733_0cb5439472': ([['startseq',
#     'man',
#     'in',
#     'pink',
#     'shirt',
#     'climbs',
#     'rock',
#     'face',
#     'endseq'],
#    ['startseq',
#     'man',
#     'is',
#     'rock',
#     'climbing',
#     'high',
#     'in',
#     'the',
#     'air',
#     'endseq'],
#    ['startseq',
#     'person',
#     'in',
#     'red',
#     'shirt',
#     'climbing',
#     'up',
#     'rock',
#     'face',
#     'covered',
#     'in',
#     'assist',
#     'handles',
#     'endseq'],
#    ['startseq', 'rock', 'climber', 'in', 'red', 'shirt', 'endseq'],
#    ['startseq',
#     'rock',
#     'climber',
#     'practices',
#     'on',
#     'rock',
#     'climbing',
#     'wall',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'climbing',
#    'rock',
#    'endseq'])}

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('Flickr8k/Flicker8k_Dataset/1122944218_8eb3607403.jpg')
img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
plt.imshow(img)

# %%
rd_test['1122944218_8eb3607403']
# Out:
# ([['startseq',
#    'baby',
#    'in',
#    'white',
#    'garment',
#    'holds',
#    'flag',
#    'with',
#    'crescent',
#    'moon',
#    'and',
#    'star',
#    'endseq'],
#   ['startseq',
#    'baby',
#    'is',
#    'holding',
#    'small',
#    'black',
#    'flag',
#    'with',
#    'moon',
#    'and',
#    'star',
#    'on',
#    'it',
#    'endseq'],
#   ['startseq',
#    'baby',
#    'wearing',
#    'white',
#    'gown',
#    'waves',
#    'muslim',
#    'flag',
#    'endseq'],
#   ['startseq',
#    'little',
#    'toddler',
#    'dressed',
#    'in',
#    'white',
#    'is',
#    'smiling',
#    'while',
#    'lady',
#    'helps',
#    'him',
#    'wave',
#    'flag',
#    'endseq'],
#   ['startseq',
#    'baby',
#    'in',
#    'white',
#    'outfit',
#    'holding',
#    'black',
#    'and',
#    'white',
#    'flag',
#    'endseq']],
#  ['startseq',
#   'young',
#   'boy',
#   'in',
#   'red',
#   'shirt',
#   'is',
#   'playing',
#   'with',
#   'her',
#   'arms',
#   'endseq'])

# %%
pickle.dump(rd_test,open('rd_IncResFT_test.pkl','wb'))

# %%
uploadId = '1Hw09omY9-FIa_Z4o0PswO-Xx3Gb6DHU3'
uploaded = drive.CreateFile({'parents':[{'id': uploadId}] , 'title' : 'rd_IncResFT_test.pkl'})
uploaded.SetContentFile('rd_IncResFT_test.pkl')
uploaded.Upload()

# %%
len(rd_test)
# Out:
# 1000
