# %%
# !nvidia-smi
# Out:
# Sat May  4 17:54:41 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.56       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    26W /  70W |   1990MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#https://drive.google.com/open?id=1zglOX-AkDkXV3SAiUcQEm0gssYF3FrVZ

download = drive.CreateFile({'id': '1zglOX-AkDkXV3SAiUcQEm0gssYF3FrVZ'})
download.GetContentFile('Flickr8k.zip')
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.12.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.5)

# %%
# !unzip Flickr8k.zip

# %% [markdown]
# # InceptionResnetV2

# %%
#https://drive.google.com/open?id=15vzxif8H2WfdUEbfCUKnYMxL901JXojp
download = drive.CreateFile({'id': '15vzxif8H2WfdUEbfCUKnYMxL901JXojp'})
download.GetContentFile('model-ep003-loss3.433-val_loss3.683.h5')

#https://drive.google.com/open?id=1c7s9YT8eT2gfRp-YNvhzGWZUJzC3_gxp
download = drive.CreateFile({'id': '1c7s9YT8eT2gfRp-YNvhzGWZUJzC3_gxp'})
download.GetContentFile('features18.pkl')

#https://drive.google.com/open?id=1aaX6_6lQ5klkDE_rRVdpLQOUjP3njzr6
download = drive.CreateFile({'id': '1aaX6_6lQ5klkDE_rRVdpLQOUjP3njzr6'})
download.GetContentFile('descriptions18.txt')

#https://drive.google.com/open?id=1jQ6y_ZC57EwtMvWpogXyuWuFyiOiHRVz
download = drive.CreateFile({'id': '1jQ6y_ZC57EwtMvWpogXyuWuFyiOiHRVz'})
download.GetContentFile('tokenizer18.pkl')

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

import io
import zipfile
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import pickle
import numpy as np

def load_doc(fname):
  fp=open(fname,'r')
  txt=fp.read()
  fp.close()
  return txt

fname='Flickr8k/Flickr8k_text/Flickr8k.token.txt'
doc=load_doc(fname)

def evaluate_model(model,descriptions,photos,tokenizer,max_len):
  rd={}
  actual,predicted=list(),list()
  for key,desc_list in descriptions.items():
    yhat=generate_desc(model,tokenizer,photos[key],max_len)
    
    references=[d.split() for d in desc_list]
    
    rd[key]=(references,yhat.split())
  
    actual.append(references)
    predicted.append(yhat.split())
    
    
  return actual,predicted,rd

def word_for_id(integer,tokenizer):
  for word,index in tokenizer.word_index.items():
    if index==integer:
      return word
  return None
  
def generate_desc(model,tokenizer,photo,max_len):
  in_text='startseq'
  
  for i in range(max_len):
    sequence=tokenizer.texts_to_sequences([in_text])[0]
    
    sequence=pad_sequences([sequence],maxlen=max_len)
    
    yhat=model.predict([photo,sequence],verbose=0)
    yhat=np.argmax(yhat)
    
    word=word_for_id(yhat,tokenizer)
    
    if word is None:
      break
      
    in_text += ' '+word
    
    if word=='endseq':
      break
      
  return in_text

def load_set(fname):
  doc=load_doc(fname)
  dataset=list()
  for line in doc.split('\n'):
    if len(line)<1:
      continue
    identifier=line.split('.')[0]
    dataset.append(identifier)

  return dataset,set(dataset)

def load_clean_descriptions(fname,dataset):
  doc=load_doc(fname)
  descriptions = dict()
  for line in doc.split('\n'):
    tokens=line.split()
    img_id,img_desc=tokens[0],tokens[1:]
    if img_id in dataset:
      if img_id not in descriptions:
        descriptions[img_id]=list()
      
      desc='startseq ' + ' '.join(img_desc) + ' endseq'
      #print(img_id,img_desc)
      descriptions[img_id].append(desc)
      #print(img_id,descriptions[img_id])
  
  return descriptions

def load_photo_features(fname,dataset):
  all_features=pickle.load(open(fname,'rb'))
  features={k:all_features[k] for k in dataset}
  return features

fname='Flickr8k/Flickr8k_text/Flickr_8k.devImages.txt'
vallist,val=load_set(fname)
print(len(vallist),len(val))
val_descriptions=load_clean_descriptions('descriptions18.txt',vallist)
print(len(val_descriptions))
val_features=load_photo_features('features18.pkl',vallist)
print(len(val_features))
# Out:
# 1000 1000
# 1000
# 1000

# %%
len(vallist)
# Out:
# 1000

# %%
import numpy as np
import pandas as pd
import cv2
import time
import os
import matplotlib.pyplot as plt
import pickle
import string

from keras.applications.inception_resnet_v2 import InceptionResNetV2,preprocess_input

#from keras.applications.vgg16 import VGG16,preprocess_input
from keras.preprocessing.image import load_img,img_to_array
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical,plot_model
from keras.models import Model
from keras.layers import Input,Dense,LSTM,Embedding,Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu
#import shutil #dont use shutil it deletes files
from collections import Counter
# Out:
# Using TensorFlow backend.

# %%
tokenizer=pickle.load(open('tokenizer18.pkl','rb'))

# %%
max_len=34

# %%
# test set
start=time.time()
InceptionResnetV2=load_model('model-ep003-loss3.433-val_loss3.683.h5')
actual,predicted,rd_val=evaluate_model(InceptionResnetV2,val_descriptions,val_features,tokenizer,max_len)
end=time.time()
print(end-start)
print('BLEU - 1 : %f' % corpus_bleu(actual,predicted,weights=(1.0,0,0,0)))
print('BLEU - 2 : %f' % corpus_bleu(actual,predicted,weights=(0.5,0.5,0,0)))
print('BLEU - 3 : %f' % corpus_bleu(actual,predicted,weights=(0.3,0.3,0.3,0)))
print('BLEU - 4 : %f' % corpus_bleu(actual,predicted,weights=(0.25,0.25,0.25,0.25)))
print(len(actual),len(predicted))
pickle.dump(actual,open('actual.pkl','wb'))
pickle.dump(predicted,open('predicted.pkl','wb'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 283.46163153648376
# BLEU - 1 : 0.411673
# BLEU - 2 : 0.223612
# BLEU - 3 : 0.153555
# BLEU - 4 : 0.068918
# 1000 1000

# %%
rd_val
# Out:
# {'1022454332_6af2c1449a': ([['startseq',
#     'child',
#     'and',
#     'woman',
#     'are',
#     'at',
#     'waters',
#     'edge',
#     'in',
#     'big',
#     'city',
#     'endseq'],
#    ['startseq',
#     'large',
#     'lake',
#     'with',
#     'lone',
#     'duck',
#     'swimming',
#     'in',
#     'it',
#     'with',
#     'several',
#     'people',
#     'around',
#     'the',
#     'edge',
#     'of',
#     'it',
#     'endseq'],
#    ['startseq', 'little', 'boy', 'at', 'lake', 'watching', 'duck', 'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'waves',
#     'his',
#     'hand',
#     'at',
#     'the',
#     'duck',
#     'in',
#     'the',
#     'water',
#     'surrounded',
#     'by',
#     'green',
#     'park',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'are',
#     'at',
#     'the',
#     'edge',
#     'of',
#     'lake',
#     'facing',
#     'the',
#     'water',
#     'and',
#     'the',
#     'city',
#     'skyline',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '103106960_e8a41d64f8': ([['startseq',
#     'boy',
#     'with',
#     'stick',
#     'kneeling',
#     'in',
#     'front',
#     'of',
#     'goalie',
#     'net',
#     'endseq'],
#    ['startseq',
#     'child',
#     'in',
#     'red',
#     'jacket',
#     'playing',
#     'street',
#     'hockey',
#     'guarding',
#     'goal',
#     'endseq'],
#    ['startseq',
#     'young',
#     'kid',
#     'playing',
#     'the',
#     'goalie',
#     'in',
#     'hockey',
#     'rink',
#     'endseq'],
#    ['startseq',
#     'young',
#     'male',
#     'kneeling',
#     'in',
#     'front',
#     'of',
#     'hockey',
#     'goal',
#     'with',
#     'hockey',
#     'stick',
#     'in',
#     'his',
#     'right',
#     'hand',
#     'endseq'],
#    ['startseq',
#     'hockey',
#     'goalie',
#     'boy',
#     'in',
#     'red',
#     'jacket',
#     'crouches',
#     'by',
#     'goal',
#     'with',
#     'stick',
#     'endseq']],
#   ['startseq',
#    'two',
#    'girls',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '1032122270_ea6f0beedb': ([['startseq',
#     'woman',
#     'crouches',
#     'near',
#     'three',
#     'dogs',
#     'in',
#     'field',
#     'endseq'],
#    ['startseq',
#     'three',
#     'dogs',
#     'are',
#     'playing',
#     'on',
#     'grassy',
#     'hill',
#     'with',
#     'blue',
#     'sky',
#     'endseq'],
#    ['startseq',
#     'three',
#     'dogs',
#     'are',
#     'standing',
#     'in',
#     'the',
#     'grass',
#     'and',
#     'person',
#     'is',
#     'sitting',
#     'next',
#     'to',
#     'them',
#     'endseq'],
#    ['startseq', 'three', 'dogs', 'on', 'grassy', 'hill', 'endseq'],
#    ['startseq',
#     'three',
#     'dogs',
#     'stand',
#     'in',
#     'grassy',
#     'field',
#     'while',
#     'person',
#     'kneels',
#     'nearby',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1034276567_49bb87c51c': ([['startseq',
#     'boy',
#     'bites',
#     'hard',
#     'into',
#     'treat',
#     'while',
#     'he',
#     'sits',
#     'outside',
#     'endseq'],
#    ['startseq', 'child', 'biting', 'into', 'baked', 'good', 'endseq'],
#    ['startseq',
#     'small',
#     'boy',
#     'putting',
#     'something',
#     'in',
#     'his',
#     'mouth',
#     'with',
#     'both',
#     'hands',
#     'endseq'],
#    ['startseq',
#     'the',
#     'boy',
#     'eats',
#     'his',
#     'food',
#     'outside',
#     'at',
#     'the',
#     'table',
#     'endseq'],
#    ['startseq',
#     'the',
#     'boy',
#     'is',
#     'eating',
#     'pizza',
#     'over',
#     'tin',
#     'dish',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'sidewalk',
#    'endseq']),
#  '1045521051_108ebc19be': ([['startseq',
#     'person',
#     'eats',
#     'takeout',
#     'while',
#     'watching',
#     'small',
#     'television',
#     'endseq'],
#    ['startseq',
#     'person',
#     'sits',
#     'on',
#     'the',
#     'floor',
#     'and',
#     'eats',
#     'in',
#     'front',
#     'of',
#     'television',
#     'endseq'],
#    ['startseq',
#     'television',
#     'with',
#     'picture',
#     'of',
#     'girl',
#     'on',
#     'it',
#     'endseq'],
#    ['startseq',
#     'young',
#     'man',
#     'sits',
#     'on',
#     'the',
#     'floor',
#     'by',
#     'the',
#     'television',
#     'with',
#     'fast',
#     'food',
#     'meal',
#     'in',
#     'front',
#     'of',
#     'him',
#     'endseq'],
#    ['startseq',
#     'someone',
#     'is',
#     'laying',
#     'in',
#     'front',
#     'of',
#     'the',
#     'tv',
#     'eating',
#     'food',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1056249424_ef2a2e041c': ([['startseq',
#     'the',
#     'children',
#     'are',
#     'playing',
#     'in',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'one',
#     'with',
#     'yellow',
#     'and',
#     'orange',
#     'ball',
#     'play',
#     'in',
#     'some',
#     'water',
#     'in',
#     'front',
#     'of',
#     'field',
#     'endseq'],
#    ['startseq', 'two', 'boys', 'play', 'in', 'puddle', 'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'play',
#     'with',
#     'balloon',
#     'in',
#     'mud',
#     'on',
#     'sunny',
#     'day',
#     'endseq'],
#    ['startseq',
#     'two',
#     'kids',
#     'are',
#     'running',
#     'and',
#     'playing',
#     'in',
#     'some',
#     'water',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '107582366_d86f2d3347': ([['startseq',
#     'group',
#     'of',
#     'eight',
#     'people',
#     'are',
#     'gathered',
#     'around',
#     'table',
#     'at',
#     'night',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'gathered',
#     'around',
#     'in',
#     'the',
#     'dark',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'sit',
#     'around',
#     'table',
#     'outside',
#     'on',
#     'porch',
#     'at',
#     'night',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'sit',
#     'outdoors',
#     'together',
#     'at',
#     'night',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'sitting',
#     'at',
#     'table',
#     'in',
#     'darkened',
#     'room',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt']),
#  '1077546505_a4f6c4daa9': ([['startseq',
#     'boy',
#     'in',
#     'blue',
#     'shorts',
#     'slides',
#     'down',
#     'slide',
#     'into',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'in',
#     'blue',
#     'swimming',
#     'trunks',
#     'slides',
#     'down',
#     'yellow',
#     'slide',
#     'into',
#     'wading',
#     'pool',
#     'with',
#     'inflatable',
#     'toys',
#     'floating',
#     'in',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'rides',
#     'down',
#     'slide',
#     'into',
#     'small',
#     'backyard',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'sliding',
#     'down',
#     'slide',
#     'into',
#     'pool',
#     'with',
#     'colorful',
#     'tubes',
#     'endseq'],
#    ['startseq',
#     'child',
#     'is',
#     'falling',
#     'off',
#     'slide',
#     'onto',
#     'colored',
#     'balloons',
#     'floating',
#     'on',
#     'pool',
#     'of',
#     'water',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'pink',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '1077931201_1e0bb83105': ([['startseq',
#     'man',
#     'in',
#     'wetsuit',
#     'is',
#     'throwing',
#     'baby',
#     'wearing',
#     'wetsuit',
#     'up',
#     'into',
#     'the',
#     'air',
#     'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'wetsuit',
#     'is',
#     'throwing',
#     'toddler',
#     'up',
#     'in',
#     'the',
#     'air',
#     'and',
#     'is',
#     'ready',
#     'to',
#     'catch',
#     'him',
#     'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'water',
#     'throwing',
#     'little',
#     'boy',
#     'up',
#     'in',
#     'the',
#     'air',
#     'and',
#     'waiting',
#     'for',
#     'him',
#     'to',
#     'come',
#     'down',
#     'so',
#     'he',
#     'can',
#     'catch',
#     'him',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'is',
#     'in',
#     'the',
#     'pool',
#     'and',
#     'throwing',
#     'small',
#     'boy',
#     'into',
#     'the',
#     'air',
#     'endseq'],
#    ['startseq',
#     'while',
#     'water',
#     'droplets',
#     'fly',
#     'man',
#     'throws',
#     'little',
#     'boy',
#     'up',
#     'in',
#     'the',
#     'air',
#     'endseq']],
#   ['startseq', 'man', 'is', 'jumping', 'into', 'the', 'air', 'endseq']),
#  '1087539207_9f77ab3aaf': ([['startseq',
#     'family',
#     'playing',
#     'on',
#     'tractor',
#     'on',
#     'beautiful',
#     'day',
#     'endseq'],
#    ['startseq', 'children', 'ride', 'tractor', 'in', 'field', 'endseq'],
#    ['startseq',
#     'several',
#     'children',
#     'playing',
#     'on',
#     'polaris',
#     'vehicle',
#     'outdoors',
#     'endseq'],
#    ['startseq',
#     'the',
#     'children',
#     'played',
#     'on',
#     'the',
#     'four',
#     'wheeler',
#     'in',
#     'the',
#     'field',
#     'endseq'],
#    ['startseq',
#     'the',
#     'four',
#     'kids',
#     'are',
#     'riding',
#     'on',
#     'an',
#     'atv',
#     'in',
#     'field',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '1088767354_2acee738cf': ([['startseq',
#     'woman',
#     'in',
#     'red',
#     'costume',
#     'to',
#     'the',
#     'left',
#     'of',
#     'man',
#     'and',
#     'woman',
#     'standing',
#     'together',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'wearing',
#     'red',
#     'costume',
#     'looks',
#     'at',
#     'two',
#     'other',
#     'people',
#     'standing',
#     'on',
#     'street',
#     'endseq'],
#    ['startseq',
#     'young',
#     'woman',
#     'in',
#     'red',
#     'sequined',
#     'costume',
#     'and',
#     'feather',
#     'stands',
#     'on',
#     'the',
#     'sidewalk',
#     'endseq'],
#    ['startseq',
#     'the',
#     'girl',
#     'in',
#     'the',
#     'salmon',
#     'colored',
#     'bikini',
#     'is',
#     'standing',
#     'next',
#     'to',
#     'two',
#     'young',
#     'people',
#     'one',
#     'is',
#     'wearing',
#     'black',
#     'outfit',
#     'and',
#     'the',
#     'other',
#     'is',
#     'drinking',
#     'pop',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'people',
#     'are',
#     'approached',
#     'by',
#     'flamboyant',
#     'young',
#     'woman',
#     'dressed',
#     'in',
#     'red',
#     'bikini',
#     'and',
#     'red',
#     'feathered',
#     'headress',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt']),
#  '1089755335_0bfbfd30e6': ([['startseq',
#     'mother',
#     'and',
#     'children',
#     'is',
#     'fishing',
#     'on',
#     'boardwalk',
#     'at',
#     'night',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'and',
#     'three',
#     'children',
#     'stand',
#     'on',
#     'deck',
#     'with',
#     'fishing',
#     'pole',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'stands',
#     'with',
#     'children',
#     'on',
#     'boardwalk',
#     'at',
#     'night',
#     'overlooking',
#     'the',
#     'sea',
#     'endseq'],
#    ['startseq',
#     'some',
#     'people',
#     'on',
#     'pier',
#     'at',
#     'night',
#     'with',
#     'one',
#     'girl',
#     'fishing',
#     'off',
#     'it',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'with',
#     'three',
#     'children',
#     'fishing',
#     'over',
#     'boardwalk',
#     'in',
#     'the',
#     'evening',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '1100214449_d10861e633': ([['startseq',
#     'boy',
#     'in',
#     'striped',
#     'shirt',
#     'is',
#     'jumping',
#     'in',
#     'front',
#     'of',
#     'water',
#     'fountain',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'is',
#     'jumping',
#     'off',
#     'the',
#     'side',
#     'of',
#     'running',
#     'stone',
#     'water',
#     'fountain',
#     'in',
#     'front',
#     'of',
#     'building',
#     'endseq'],
#    ['startseq',
#     'happy',
#     'boy',
#     'is',
#     'jumping',
#     'in',
#     'front',
#     'od',
#     'city',
#     'fountain',
#     'endseq'],
#    ['startseq',
#     'little',
#     'boy',
#     'is',
#     'jumping',
#     'in',
#     'front',
#     'of',
#     'fountain',
#     'endseq'],
#    ['startseq',
#     'little',
#     'boy',
#     'is',
#     'playfully',
#     'jumping',
#     'off',
#     'the',
#     'side',
#     'of',
#     'fountain',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'pink',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '111497985_38e9f88856': ([['startseq',
#     'kid',
#     'rock',
#     'climbing',
#     'against',
#     'the',
#     'backdrop',
#     'of',
#     'green',
#     'valley',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'in',
#     'striped',
#     'shirt',
#     'climbs',
#     'up',
#     'mountain',
#     'endseq'],
#    ['startseq', 'young', 'man', 'climbs', 'rocky', 'hill', 'endseq'],
#    ['startseq',
#     'the',
#     'person',
#     'has',
#     'striped',
#     'shirt',
#     'on',
#     'and',
#     'is',
#     'holding',
#     'on',
#     'to',
#     'rope',
#     'on',
#     'mountain',
#     'endseq'],
#    ['startseq',
#     'the',
#     'person',
#     'in',
#     'the',
#     'striped',
#     'shirt',
#     'is',
#     'mountain',
#     'climbing',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'top',
#    'of',
#    'mountain',
#    'endseq']),
#  '1130369873_d80a1aa59c': ([['startseq',
#     'brown',
#     'dog',
#     'is',
#     'running',
#     'through',
#     'neckdeep',
#     'water',
#     'carrying',
#     'tennis',
#     'ball',
#     'endseq'],
#    ['startseq',
#     'brown',
#     'dog',
#     'splashes',
#     'in',
#     'the',
#     'water',
#     'while',
#     'carrying',
#     'ball',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'brown',
#     'dog',
#     'swims',
#     'through',
#     'water',
#     'outdoors',
#     'with',
#     'tennis',
#     'ball',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'red',
#     'dog',
#     'holding',
#     'ball',
#     'splashes',
#     'through',
#     'vegetation',
#     'filled',
#     'water',
#     'endseq'],
#    ['startseq',
#     'brown',
#     'dog',
#     'with',
#     'tennis',
#     'ball',
#     'in',
#     'mouth',
#     'in',
#     'water',
#     'and',
#     'bushes',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'water', 'endseq']),
#  '1131155939_b4b457b05e': ([['startseq',
#     'black',
#     'dog',
#     'runs',
#     'into',
#     'the',
#     'ocean',
#     'next',
#     'to',
#     'pile',
#     'of',
#     'seaweed',
#     'endseq'],
#    ['startseq',
#     'black',
#     'lav',
#     'runs',
#     'into',
#     'the',
#     'water',
#     'on',
#     'the',
#     'beach',
#     'with',
#     'swimmers',
#     'in',
#     'the',
#     'distance',
#     'and',
#     'sea',
#     'kelp',
#     'in',
#     'the',
#     'foreground',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'at',
#     'the',
#     'shore',
#     'of',
#     'an',
#     'ocean',
#     'with',
#     'seaweed',
#     'in',
#     'foreground',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'is',
#     'running',
#     'in',
#     'the',
#     'waves',
#     'at',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'pile',
#     'of',
#     'seaweed',
#     'sits',
#     'on',
#     'the',
#     'sand',
#     'behind',
#     'it',
#     'big',
#     'black',
#     'dog',
#     'is',
#     'running',
#     'in',
#     'the',
#     'water',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'water', 'endseq']),
#  '1138784872_69ade3f2ab': ([['startseq',
#     'girl',
#     'in',
#     'green',
#     'walks',
#     'down',
#     'city',
#     'street',
#     'endseq'],
#    ['startseq',
#     'small',
#     'child',
#     'in',
#     'green',
#     'clothing',
#     'walks',
#     'past',
#     'store',
#     'opening',
#     'and',
#     'woman',
#     'in',
#     'pink',
#     'pants',
#     'endseq'],
#    ['startseq', 'small', 'child', 'walks', 'down', 'sidewalk', 'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'is',
#     'walking',
#     'in',
#     'front',
#     'of',
#     'some',
#     'stores',
#     'endseq'],
#    ['startseq',
#     'the',
#     'child',
#     'in',
#     'the',
#     'green',
#     'one',
#     'piece',
#     'suit',
#     'is',
#     'walking',
#     'past',
#     'store',
#     'window',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1164131282_b30926f332': ([['startseq',
#     'grey',
#     'dog',
#     'beside',
#     'black',
#     'and',
#     'white',
#     'dog',
#     'running',
#     'in',
#     'green',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'two',
#     'dogs',
#     'are',
#     'wrestling',
#     'in',
#     'grassy',
#     'field',
#     'endseq'],
#    ['startseq',
#     'two',
#     'dogs',
#     'playing',
#     'in',
#     'field',
#     'wrestling',
#     'with',
#     'each',
#     'other',
#     'endseq'],
#    ['startseq',
#     'two',
#     'dogs',
#     'run',
#     'along',
#     'grassy',
#     'field',
#     'while',
#     'one',
#     'bites',
#     'the',
#     'other',
#     'endseq'],
#    ['startseq', 'two', 'dogs', 'wrestle', 'in', 'field', 'endseq']],
#   ['startseq',
#    'two',
#    'dogs',
#    'are',
#    'playing',
#    'with',
#    'ball',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '1177994172_10d143cb8d': ([['startseq',
#     'two',
#     'blonde',
#     'boys',
#     'one',
#     'in',
#     'camouflage',
#     'shirt',
#     'and',
#     'the',
#     'other',
#     'in',
#     'blue',
#     'are',
#     'having',
#     'water',
#     'fight',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'are',
#     'squirting',
#     'water',
#     'guns',
#     'at',
#     'each',
#     'other',
#     'endseq'],
#    ['startseq',
#     'two',
#     'boys',
#     'spraying',
#     'each',
#     'other',
#     'with',
#     'water',
#     'endseq'],
#    ['startseq',
#     'two',
#     'children',
#     'wearing',
#     'jeans',
#     'squirt',
#     'water',
#     'at',
#     'each',
#     'other',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'boys',
#     'are',
#     'squirting',
#     'water',
#     'at',
#     'each',
#     'other',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'and',
#    'hat',
#    'and',
#    'hat',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt']),
#  '1178705300_c224d9a4f1': ([['startseq',
#     'brown',
#     'dog',
#     'jumping',
#     'into',
#     'pool',
#     'after',
#     'bloe',
#     'ball',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'in',
#     'the',
#     'air',
#     'above',
#     'the',
#     'swimming',
#     'pool',
#     'endseq'],
#    ['startseq', 'dog', 'jumps', 'into', 'backyard', 'pool', 'endseq'],
#    ['startseq',
#     'tan',
#     'colored',
#     'dog',
#     'is',
#     'jumping',
#     'into',
#     'an',
#     'outdoor',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'tan',
#     'colored',
#     'dog',
#     'leaps',
#     'into',
#     'the',
#     'inground',
#     'pool',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'water', 'endseq']),
#  '1215334959_b1970965f7': ([['startseq',
#     'family',
#     'sits',
#     'on',
#     'bench',
#     'near',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'family',
#     'sits',
#     'on',
#     'bench',
#     'overlooking',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'man',
#     'woman',
#     'girl',
#     'and',
#     'boy',
#     'sit',
#     'on',
#     'concrete',
#     'bench',
#     'by',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'family',
#     'sitting',
#     'on',
#     'bench',
#     'near',
#     'the',
#     'beach',
#     'endseq'],
#    ['startseq',
#     'taking',
#     'break',
#     'while',
#     'vacationing',
#     'at',
#     'the',
#     'beach',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1232148178_4f45cc3284': ([['startseq',
#     'baby',
#     'girl',
#     'playing',
#     'at',
#     'park',
#     'endseq'],
#    ['startseq',
#     'closeup',
#     'of',
#     'child',
#     'on',
#     'playground',
#     'with',
#     'adult',
#     'supervision',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'poses',
#     'for',
#     'picture',
#     'in',
#     'front',
#     'of',
#     'playground',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'is',
#     'smiling',
#     'in',
#     'front',
#     'of',
#     'the',
#     'camera',
#     'at',
#     'park',
#     'endseq'],
#    ['startseq',
#     'there',
#     'is',
#     'little',
#     'blond',
#     'hair',
#     'girl',
#     'with',
#     'green',
#     'sweatshirt',
#     'and',
#     'red',
#     'shirt',
#     'playing',
#     'on',
#     'playground',
#     'endseq']],
#   ['startseq',
#    'little',
#    'boy',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '123997871_6a9ca987b1': ([['startseq',
#     'girls',
#     'wearing',
#     'sports',
#     'uniforms',
#     'and',
#     'eye',
#     'protection',
#     'endseq'],
#    ['startseq',
#     'several',
#     'female',
#     'lacrosse',
#     'players',
#     'are',
#     'going',
#     'after',
#     'ball',
#     'endseq'],
#    ['startseq',
#     'these',
#     'girls',
#     'are',
#     'in',
#     'uniforms',
#     'and',
#     'are',
#     'playing',
#     'field',
#     'hockey',
#     'endseq'],
#    ['startseq',
#     'the',
#     'woman',
#     'lacrosse',
#     'player',
#     'in',
#     'blue',
#     'is',
#     'about',
#     'to',
#     'catch',
#     'the',
#     'ball',
#     'endseq'],
#    ['startseq', 'women', 'play', 'lacrosse', 'endseq']],
#   ['startseq', 'two', 'men', 'play', 'game', 'endseq']),
#  '1248357227_2b4175fc39': ([['startseq',
#     'the',
#     'kids',
#     'play',
#     'in',
#     'the',
#     'wooded',
#     'area',
#     'near',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'three',
#     'children',
#     'in',
#     'jackets',
#     'looking',
#     'at',
#     'water',
#     'edge',
#     'looking',
#     'at',
#     'their',
#     'reflections',
#     'in',
#     'lake',
#     'endseq'],
#    ['startseq',
#     'three',
#     'children',
#     'looking',
#     'into',
#     'the',
#     'water',
#     'on',
#     'wooded',
#     'lakeside',
#     'endseq'],
#    ['startseq',
#     'three',
#     'children',
#     'play',
#     'near',
#     'placid',
#     'lake',
#     'in',
#     'wooded',
#     'area',
#     'endseq'],
#    ['startseq',
#     'three',
#     'children',
#     'stand',
#     'next',
#     'to',
#     'lake',
#     'with',
#     'their',
#     'reflections',
#     'on',
#     'the',
#     'water',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'water', 'endseq']),
#  '124972799_de706b6d0b': ([['startseq',
#     'cat',
#     'under',
#     'the',
#     'bench',
#     'hissing',
#     'with',
#     'dog',
#     'growling',
#     'and',
#     'trying',
#     'to',
#     'get',
#     'it',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'toys',
#     'with',
#     'cat',
#     'hiding',
#     'under',
#     'bench',
#     'endseq'],
#    ['startseq',
#     'snarling',
#     'brown',
#     'and',
#     'black',
#     'dog',
#     'corners',
#     'brown',
#     'longhaired',
#     'cat',
#     'under',
#     'wooden',
#     'bench',
#     'endseq'],
#    ['startseq', 'snarling', 'dog', 'approaches', 'hissing', 'cat', 'endseq'],
#    ['startseq',
#     'black',
#     'and',
#     'brown',
#     'dog',
#     'growling',
#     'at',
#     'brown',
#     'cat',
#     'hiding',
#     'under',
#     'wooden',
#     'bench',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '127450902_533ceeddfc': ([['startseq',
#     'winter',
#     'landscape',
#     'with',
#     'four',
#     'people',
#     'walking',
#     'in',
#     'the',
#     'snow',
#     'endseq'],
#    ['startseq',
#     'beautiful',
#     'snowy',
#     'landscape',
#     'with',
#     'people',
#     'treading',
#     'through',
#     'the',
#     'snow',
#     'endseq'],
#    ['startseq',
#     'crosscountry',
#     'skiers',
#     'are',
#     'traveling',
#     'towards',
#     'the',
#     'mountains',
#     'at',
#     'sunset',
#     'endseq'],
#    ['startseq',
#     'four',
#     'people',
#     'walking',
#     'across',
#     'thick',
#     'snow',
#     'during',
#     'sunset',
#     'endseq'],
#    ['startseq',
#     'the',
#     'sun',
#     'is',
#     'almost',
#     'behind',
#     'the',
#     'snowy',
#     'mountains',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'side',
#    'of',
#    'mountain',
#    'endseq']),
#  '1295698260_e10c53c137': ([['startseq',
#     'crowd',
#     'of',
#     'people',
#     'look',
#     'at',
#     'something',
#     'out',
#     'of',
#     'frame',
#     'one',
#     'man',
#     'takes',
#     'picture',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'stop',
#     'to',
#     'look',
#     'at',
#     'something',
#     'while',
#     'one',
#     'takes',
#     'picture',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'with',
#     'shopping',
#     'bag',
#     'labeled',
#     'sale',
#     'stands',
#     'in',
#     'crowd',
#     'next',
#     'to',
#     'young',
#     'man',
#     'with',
#     'camera',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'is',
#     'taking',
#     'picture',
#     'while',
#     'the',
#     'crowd',
#     'gathers',
#     'endseq'],
#    ['startseq',
#     'the',
#     'woman',
#     'in',
#     'glasses',
#     'is',
#     'holding',
#     'red',
#     'and',
#     'white',
#     'sale',
#     'bag',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'and',
#    'hat',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black']),
#  '1303548017_47de590273': ([['startseq',
#     'girl',
#     'poses',
#     'on',
#     'the',
#     'train',
#     'tracks',
#     'near',
#     'station',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'wearing',
#     'green',
#     'shirt',
#     'stands',
#     'on',
#     'the',
#     'railroad',
#     'tracks',
#     'endseq'],
#    ['startseq',
#     'young',
#     'female',
#     'in',
#     'green',
#     'tank',
#     'top',
#     'and',
#     'shorts',
#     'standing',
#     'in',
#     'the',
#     'middle',
#     'of',
#     'the',
#     'railroad',
#     'tracks',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'with',
#     'green',
#     'tank',
#     'top',
#     'standing',
#     'in',
#     'the',
#     'middle',
#     'of',
#     'train',
#     'track',
#     'with',
#     'multicolor',
#     'train',
#     'cars',
#     'to',
#     'the',
#     'right',
#     'endseq'],
#    ['startseq',
#     'the',
#     'girl',
#     'with',
#     'the',
#     'green',
#     'tank',
#     'top',
#     'and',
#     'grey',
#     'shorts',
#     'is',
#     'standing',
#     'in',
#     'the',
#     'middle',
#     'of',
#     'the',
#     'empty',
#     'railroad',
#     'track',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'endseq']),
#  '1306145560_1e37081b91': ([['startseq',
#     'black',
#     'dog',
#     'carries',
#     'an',
#     'orange',
#     'tennis',
#     'ball',
#     'in',
#     'his',
#     'mouth',
#     'as',
#     'he',
#     'swims',
#     'endseq'],
#    ['startseq', 'black', 'dog', 'swims', 'in', 'the', 'water', 'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'with',
#     'tennis',
#     'ball',
#     'in',
#     'its',
#     'mouth',
#     'swims',
#     'through',
#     'water',
#     'endseq'],
#    ['startseq',
#     'dog',
#     'swims',
#     'holding',
#     'tennis',
#     'ball',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'the',
#     'dog',
#     'is',
#     'swimming',
#     'with',
#     'the',
#     'ball',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1319634306_816f21677f': ([['startseq',
#     'brown',
#     'dog',
#     'is',
#     'sitting',
#     'in',
#     'some',
#     'long',
#     'grass',
#     'endseq'],
#    ['startseq', 'brown', 'dog', 'sits', 'still', 'on', 'hillside', 'endseq'],
#    ['startseq',
#     'large',
#     'tan',
#     'dog',
#     'sits',
#     'on',
#     'grassy',
#     'hill',
#     'endseq'],
#    ['startseq',
#     'large',
#     'yellow',
#     'dog',
#     'is',
#     'sitting',
#     'on',
#     'hill',
#     'endseq'],
#    ['startseq',
#     'the',
#     'dog',
#     'is',
#     'sitting',
#     'on',
#     'the',
#     'side',
#     'of',
#     'the',
#     'hill',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1332823164_c70a5d930e': ([['startseq',
#     'girl',
#     'standing',
#     'in',
#     'the',
#     'ocean',
#     'endseq'],
#    ['startseq', 'girl', 'walks', 'in', 'the', 'ocean', 'endseq'],
#    ['startseq',
#     'woman',
#     'in',
#     'red',
#     'jacket',
#     'stands',
#     'on',
#     'the',
#     'beach',
#     'facing',
#     'the',
#     'water',
#     'as',
#     'it',
#     'covers',
#     'her',
#     'feet',
#     'endseq'],
#    ['startseq', 'woman', 'is', 'watching', 'the', 'tide', 'endseq'],
#    ['startseq',
#     'woman',
#     'standing',
#     'on',
#     'the',
#     'shore',
#     'of',
#     'beach',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '1346051107_9cdc14e070': ([['startseq',
#     'man',
#     'is',
#     'playing',
#     'saxophone',
#     'next',
#     'to',
#     'fire',
#     'hydrant',
#     'endseq'],
#    ['startseq',
#     'man',
#     'plays',
#     'saxophone',
#     'next',
#     'to',
#     'yellow',
#     'fire',
#     'hydrant',
#     'endseq'],
#    ['startseq',
#     'man',
#     'stands',
#     'by',
#     'wall',
#     'playing',
#     'saxophone',
#     'endseq'],
#    ['startseq',
#     'man',
#     'playing',
#     'musical',
#     'instrument',
#     'standing',
#     'beside',
#     'yellow',
#     'and',
#     'red',
#     'fire',
#     'hydrant',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'is',
#     'standing',
#     'next',
#     'to',
#     'fire',
#     'hydrant',
#     'and',
#     'playing',
#     'saxophone',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '134724228_30408cd77f': ([['startseq',
#     'two',
#     'girls',
#     'are',
#     'walking',
#     'down',
#     'dirt',
#     'road',
#     'in',
#     'park',
#     'endseq'],
#    ['startseq',
#     'two',
#     'women',
#     'walking',
#     'down',
#     'dirt',
#     'road',
#     'with',
#     'man',
#     'far',
#     'behind',
#     'endseq'],
#    ['startseq',
#     'two',
#     'women',
#     'walking',
#     'on',
#     'an',
#     'outdoor',
#     'trail',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'women',
#     'are',
#     'walking',
#     'along',
#     'rural',
#     'path',
#     'bordered',
#     'by',
#     'trees',
#     'endseq'],
#    ['startseq',
#     'two',
#     'young',
#     'women',
#     'walk',
#     'along',
#     'dirt',
#     'road',
#     'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '1350811702_2ce7cfd0c5': ([['startseq',
#     'young',
#     'boy',
#     'casting',
#     'his',
#     'fishing',
#     'line',
#     'off',
#     'pier',
#     'endseq'],
#    ['startseq', 'children', 'fishing', 'off', 'bridge', 'endseq'],
#    ['startseq', 'people', 'fishing', 'over', 'white', 'fence', 'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'standing',
#     'next',
#     'to',
#     'water',
#     'casting',
#     'his',
#     'fishing',
#     'rod',
#     'with',
#     'others',
#     'next',
#     'to',
#     'him',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'wearing',
#     'waders',
#     'standing',
#     'on',
#     'dock',
#     'fishing',
#     'other',
#     'people',
#     'are',
#     'in',
#     'the',
#     'background',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'endseq']),
#  '135235570_5698072cd4': ([['startseq',
#     'man',
#     'in',
#     'field',
#     'backed',
#     'by',
#     'american',
#     'flags',
#     'endseq'],
#    ['startseq',
#     'man',
#     'is',
#     'being',
#     'thrown',
#     'frisbee',
#     'in',
#     'front',
#     'of',
#     'monument',
#     'and',
#     'flags',
#     'endseq'],
#    ['startseq',
#     'man',
#     'is',
#     'clapping',
#     'at',
#     'the',
#     'base',
#     'of',
#     'the',
#     'washington',
#     'memorial',
#     'endseq'],
#    ['startseq',
#     'man',
#     'stands',
#     'in',
#     'front',
#     'of',
#     'the',
#     'gateway',
#     'arch',
#     'endseq'],
#    ['startseq',
#     'man',
#     'tries',
#     'to',
#     'catch',
#     'football',
#     'on',
#     'grass',
#     'surrounded',
#     'by',
#     'american',
#     'flags',
#     'endseq']],
#   ['startseq',
#    'two',
#    'boys',
#    'are',
#    'playing',
#    'soccer',
#    'on',
#    'the',
#    'grass',
#    'endseq']),
#  '1355935187_2c99648138': ([['startseq',
#     'fluffy',
#     'white',
#     'dog',
#     'is',
#     'coming',
#     'out',
#     'of',
#     'blue',
#     'striped',
#     'obstacle',
#     'shute',
#     'endseq'],
#    ['startseq',
#     'small',
#     'white',
#     'dog',
#     'running',
#     'out',
#     'of',
#     'tent',
#     'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'is',
#     'emerging',
#     'from',
#     'blue',
#     'canvas',
#     'tunnel',
#     'on',
#     'an',
#     'obstacle',
#     'course',
#     'endseq'],
#    ['startseq',
#     'the',
#     'white',
#     'poodle',
#     'dog',
#     'is',
#     'coming',
#     'out',
#     'of',
#     'blue',
#     'tent',
#     'endseq'],
#    ['startseq', 'white', 'dog', 'leaving', 'bluestriped', 'tent', 'endseq']],
#   ['startseq',
#    'two',
#    'children',
#    'are',
#    'playing',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '136644885_f7d2bbf546': ([['startseq',
#     'group',
#     'of',
#     'people',
#     'walking',
#     'across',
#     'rope',
#     'bridge',
#     'endseq'],
#    ['startseq', 'woman', 'is', 'crossing', 'rope', 'bridge', 'endseq'],
#    ['startseq',
#     'woman',
#     'is',
#     'crossing',
#     'rope',
#     'bridge',
#     'in',
#     'the',
#     'trees',
#     'with',
#     'other',
#     'people',
#     'waiting',
#     'at',
#     'one',
#     'end',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'wearing',
#     'white',
#     'shirt',
#     'and',
#     'jeans',
#     'crosses',
#     'rope',
#     'bridge',
#     'in',
#     'wooded',
#     'area',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'are',
#     'crossing',
#     'rope',
#     'bridge',
#     'hung',
#     'between',
#     'pine',
#     'trees',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '1370773415_967b1ffde1': ([['startseq',
#     'man',
#     'and',
#     'woman',
#     'standing',
#     'outside',
#     'restaurant',
#     'endseq'],
#    ['startseq',
#     'man',
#     'and',
#     'woman',
#     'tak',
#     'outside',
#     'of',
#     'coffee',
#     'house',
#     'endseq'],
#    ['startseq',
#     'the',
#     'woman',
#     'in',
#     'red',
#     'jacket',
#     'is',
#     'talking',
#     'to',
#     'man',
#     'outside',
#     'of',
#     'store',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'are',
#     'standing',
#     'outside',
#     'of',
#     'coffee',
#     'house',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'stand',
#     'outside',
#     'restaurant',
#     'in',
#     'the',
#     'city',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1377668044_36398401dd': ([['startseq',
#     'dog',
#     'jumping',
#     'in',
#     'the',
#     'air',
#     'to',
#     'retrieve',
#     'stick',
#     'from',
#     'man',
#     'endseq'],
#    ['startseq', 'dog', 'leaps', 'for', 'stick', 'held', 'by', 'man', 'endseq'],
#    ['startseq',
#     'man',
#     'in',
#     'shorts',
#     'with',
#     'dog',
#     'jumping',
#     'to',
#     'get',
#     'the',
#     'stick',
#     'in',
#     'his',
#     'hand',
#     'endseq'],
#    ['startseq',
#     'man',
#     'playing',
#     'with',
#     'brown',
#     'dog',
#     'on',
#     'dirt',
#     'path',
#     'endseq'],
#    ['startseq',
#     'the',
#     'dog',
#     'is',
#     'jumping',
#     'for',
#     'the',
#     'item',
#     'the',
#     'man',
#     'is',
#     'holding',
#     'above',
#     'his',
#     'head',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1378557186_4bd1da6834': ([['startseq', 'man', 'gun', 'and', 'dog', 'endseq'],
#    ['startseq',
#     'man',
#     'aiming',
#     'rifle',
#     'with',
#     'dog',
#     'standing',
#     'beside',
#     'him',
#     'endseq'],
#    ['startseq',
#     'man',
#     'shoots',
#     'rifle',
#     'while',
#     'dog',
#     'looks',
#     'on',
#     'endseq'],
#    ['startseq',
#     'man',
#     'aiming',
#     'rifle',
#     'with',
#     'his',
#     'dog',
#     'at',
#     'his',
#     'side',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'is',
#     'aiming',
#     'to',
#     'shoot',
#     'something',
#     'while',
#     'his',
#     'dog',
#     'watches',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1387443857_602ab6f9bf': ([['startseq',
#     'an',
#     'old',
#     'man',
#     'is',
#     'sitting',
#     'on',
#     'stone',
#     'bench',
#     'endseq'],
#    ['startseq', 'an', 'old', 'man', 'sits', 'endseq'],
#    ['startseq',
#     'an',
#     'old',
#     'man',
#     'with',
#     'blue',
#     'shirt',
#     'is',
#     'looking',
#     'askance',
#     'with',
#     'people',
#     'behind',
#     'him',
#     'endseq'],
#    ['startseq',
#     'there',
#     'are',
#     'couple',
#     'of',
#     'old',
#     'men',
#     'sitting',
#     'on',
#     'concrete',
#     'bench',
#     'outside',
#     'endseq'],
#    ['startseq',
#     'two',
#     'old',
#     'men',
#     'sitting',
#     'on',
#     'the',
#     'dock',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'bench',
#    'endseq']),
#  '1388970365_162edcceb4': ([['startseq',
#     'brown',
#     'dog',
#     'and',
#     'two',
#     'black',
#     'dogs',
#     'in',
#     'an',
#     'overgrown',
#     'grassy',
#     'field',
#     'endseq'],
#    ['startseq',
#     'three',
#     'dogs',
#     'in',
#     'field',
#     'looking',
#     'at',
#     'something',
#     'in',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'three',
#     'dogs',
#     'play',
#     'in',
#     'field',
#     'near',
#     'house',
#     'to',
#     'the',
#     'right',
#     'endseq'],
#    ['startseq',
#     'three',
#     'dogs',
#     'two',
#     'black',
#     'one',
#     'brown',
#     'are',
#     'playing',
#     'in',
#     'grass',
#     'field',
#     'endseq'],
#    ['startseq',
#     'two',
#     'black',
#     'dogs',
#     'and',
#     'one',
#     'brown',
#     'dog',
#     'in',
#     'tall',
#     'grass',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '1396064003_3fd949c9dd': ([['startseq',
#     'man',
#     'hangs',
#     'upside',
#     'in',
#     'the',
#     'air',
#     'over',
#     'the',
#     'water',
#     'endseq'],
#    ['startseq',
#     'an',
#     'upside',
#     'down',
#     'man',
#     'doing',
#     'flip',
#     'on',
#     'waterski',
#     'board',
#     'endseq'],
#    ['startseq',
#     'person',
#     'did',
#     'side',
#     'flip',
#     'while',
#     'water',
#     'boarding',
#     'endseq'],
#    ['startseq', 'person', 'upside', 'down', 'on', 'water', 'board', 'endseq'],
#    ['startseq',
#     'wakeboarder',
#     'performs',
#     'flip',
#     'while',
#     'being',
#     'towed',
#     'at',
#     'high',
#     'speed',
#     'endseq']],
#   ['startseq', 'man', 'is', 'jumping', 'into', 'the', 'air', 'endseq']),
#  '140526327_3cb984de09': ([['startseq',
#     'man',
#     'looks',
#     'up',
#     'at',
#     'the',
#     'cliff',
#     'he',
#     'is',
#     'climbing',
#     'near',
#     'the',
#     'beautiful',
#     'blue',
#     'ocean',
#     'endseq'],
#    ['startseq', 'man', 'rock', 'climbing', 'near', 'the', 'ocean', 'endseq'],
#    ['startseq',
#     'man',
#     'rock',
#     'climbing',
#     'pauses',
#     'to',
#     'calculate',
#     'his',
#     'route',
#     'endseq'],
#    ['startseq',
#     'man',
#     'rock',
#     'climbing',
#     'with',
#     'city',
#     'and',
#     'bay',
#     'in',
#     'the',
#     'background',
#     'endseq'],
#    ['startseq',
#     'rock',
#     'climber',
#     'with',
#     'city',
#     'and',
#     'bay',
#     'behind',
#     'him',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1410193619_13fff6c875': ([['startseq',
#     'baby',
#     'stands',
#     'on',
#     'the',
#     'side',
#     'of',
#     'couch',
#     'and',
#     'knocks',
#     'over',
#     'lamp',
#     'endseq'],
#    ['startseq',
#     'small',
#     'child',
#     'climbs',
#     'onto',
#     'the',
#     'arm',
#     'of',
#     'red',
#     'couch',
#     'endseq'],
#    ['startseq',
#     'baby',
#     'indoors',
#     'climbing',
#     'on',
#     'red',
#     'couch',
#     'arm',
#     'reaching',
#     'for',
#     'lamp',
#     'endseq'],
#    ['startseq',
#     'small',
#     'girl',
#     'in',
#     'teal',
#     'dress',
#     'on',
#     'the',
#     'arm',
#     'of',
#     'chair',
#     'reaching',
#     'for',
#     'floor',
#     'lamp',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'sitting',
#     'on',
#     'red',
#     'couch',
#     'inside',
#     'the',
#     'house',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '141755292_7a0b3364cf': ([['startseq',
#     'man',
#     'and',
#     'woman',
#     'are',
#     'at',
#     'catered',
#     'dinner',
#     'getting',
#     'food',
#     'endseq'],
#    ['startseq',
#     'an',
#     'asian',
#     'couple',
#     'dip',
#     'their',
#     'plates',
#     'at',
#     'buffet',
#     'endseq'],
#    ['startseq',
#     'young',
#     'man',
#     'and',
#     'young',
#     'woman',
#     'serve',
#     'food',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'and',
#     'boy',
#     'serving',
#     'food',
#     'on',
#     'plate',
#     'endseq'],
#    ['startseq', 'two', 'young', 'people', 'serve', 'food', 'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'white',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'white',
#    'shirt',
#    'is',
#    'standing',
#    'in']),
#  '1420060118_aed262d606': ([['startseq',
#     'child',
#     'dressed',
#     'as',
#     'ninja',
#     'is',
#     'jumping',
#     'through',
#     'the',
#     'air',
#     'under',
#     'large',
#     'tree',
#     'endseq'],
#    ['startseq',
#     'child',
#     'in',
#     'ninja',
#     'outfit',
#     'does',
#     'jumping',
#     'kick',
#     'endseq'],
#    ['startseq',
#     'man',
#     'wearing',
#     'martial',
#     'arts',
#     'uniform',
#     'is',
#     'jumping',
#     'through',
#     'the',
#     'air',
#     'endseq'],
#    ['startseq',
#     'person',
#     'with',
#     'black',
#     'and',
#     'red',
#     'outfit',
#     'and',
#     'black',
#     'hood',
#     'is',
#     'up',
#     'in',
#     'the',
#     'air',
#     'endseq'],
#    ['startseq', 'young', 'ninja', 'jumps', 'into', 'the', 'air', 'endseq']],
#   ['startseq', 'boy', 'is', 'running', 'on', 'the', 'grass', 'endseq']),
#  '1425919702_ddb761aeec': ([['startseq',
#     'crowd',
#     'of',
#     'people',
#     'are',
#     'sitting',
#     'in',
#     'seats',
#     'in',
#     'sports',
#     'ground',
#     'bleachers',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'sitting',
#     'at',
#     'sporting',
#     'event',
#     'endseq'],
#    ['startseq',
#     'group',
#     'of',
#     'people',
#     'sit',
#     'watching',
#     'an',
#     'event',
#     'behind',
#     'tim',
#     'hortons',
#     'sign',
#     'endseq'],
#    ['startseq',
#     'people',
#     'wait',
#     'patiently',
#     'in',
#     'the',
#     'seats',
#     'for',
#     'the',
#     'show',
#     'to',
#     'begin',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'wearing',
#     'hats',
#     'are',
#     'shown',
#     'at',
#     'the',
#     'front',
#     'of',
#     'crowd',
#     'of',
#     'people',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'white',
#    'shirt',
#    'is',
#    'playing',
#    'basketball',
#    'endseq']),
#  '1426014905_da60d72957': ([['startseq',
#     'man',
#     'in',
#     'suit',
#     'along',
#     'the',
#     'railing',
#     'of',
#     'balcony',
#     'that',
#     'has',
#     'very',
#     'high',
#     'view',
#     'endseq'],
#    ['startseq', 'man', 'stands', 'alone', 'near', 'white', 'fence', 'endseq'],
#    ['startseq',
#     'man',
#     'stands',
#     'and',
#     'reads',
#     'something',
#     'by',
#     'railing',
#     'overlooking',
#     'town',
#     'endseq'],
#    ['startseq',
#     'man',
#     'stands',
#     'at',
#     'the',
#     'end',
#     'of',
#     'pier',
#     'reading',
#     'book',
#     'against',
#     'blue',
#     'sky',
#     'endseq'],
#    ['startseq',
#     'man',
#     'is',
#     'standing',
#     'next',
#     'to',
#     'the',
#     'railing',
#     'with',
#     'beautiful',
#     'clouds',
#     'in',
#     'the',
#     'background',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'sitting',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1429546659_44cb09cbe2': ([['startseq',
#     'white',
#     'dog',
#     'and',
#     'black',
#     'dog',
#     'in',
#     'field',
#     'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'with',
#     'branch',
#     'in',
#     'his',
#     'mouth',
#     'and',
#     'black',
#     'dog',
#     'endseq'],
#    ['startseq',
#     'white',
#     'dog',
#     'with',
#     'stick',
#     'in',
#     'his',
#     'mouth',
#     'standing',
#     'next',
#     'to',
#     'black',
#     'dog',
#     'endseq'],
#    ['startseq',
#     'two',
#     'dogs',
#     'are',
#     'standing',
#     'next',
#     'to',
#     'each',
#     'other',
#     'and',
#     'the',
#     'white',
#     'dog',
#     'has',
#     'stick',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'two',
#     'dogs',
#     'stand',
#     'in',
#     'the',
#     'brown',
#     'grass',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '143552829_72b6ba49d4': ([['startseq',
#     'boy',
#     'in',
#     'black',
#     'helmet',
#     'and',
#     'red',
#     'long',
#     'sleeve',
#     'shirt',
#     'rides',
#     'his',
#     'motorbike',
#     'over',
#     'rocky',
#     'stream',
#     'endseq'],
#    ['startseq',
#     'man',
#     'on',
#     'motorcycle',
#     'steers',
#     'through',
#     'swampy',
#     'terrain',
#     'endseq'],
#    ['startseq',
#     'man',
#     'rides',
#     'his',
#     'bike',
#     'over',
#     'rocks',
#     'and',
#     'creek',
#     'endseq'],
#    ['startseq',
#     'motocross',
#     'bike',
#     'is',
#     'being',
#     'ridden',
#     'between',
#     'markers',
#     'in',
#     'running',
#     'stream',
#     'endseq'],
#    ['startseq',
#     'person',
#     'is',
#     'dirt',
#     'biking',
#     'over',
#     'rocks',
#     'and',
#     'water',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'riding',
#    'bike',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '1440024115_129212c988': ([['startseq',
#     'man',
#     'plays',
#     'frisbee',
#     'with',
#     'his',
#     'dog',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'frisbee',
#     'and',
#     'dog',
#     'in',
#     'the',
#     'air',
#     'with',
#     'frisbee',
#     'in',
#     'his',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'tricolored',
#     'dog',
#     'jumps',
#     'and',
#     'catches',
#     'pink',
#     'frisbeen',
#     'that',
#     'man',
#     'in',
#     'shorts',
#     'has',
#     'thrown',
#     'endseq'],
#    ['startseq', 'small', 'dog', 'catching', 'frisbee', 'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'and',
#     'dog',
#     'which',
#     'is',
#     'leaping',
#     'into',
#     'the',
#     'air',
#     'are',
#     'playing',
#     'frisbee',
#     'endseq']],
#   ['startseq',
#    'two',
#    'black',
#    'and',
#    'white',
# ...
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'in',
#     'blue',
#     'shorts',
#     'at',
#     'the',
#     'beach',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '861661418_8a37024ace': ([['startseq',
#     'brown',
#     'dog',
#     'picks',
#     'up',
#     'twig',
#     'from',
#     'stone',
#     'surface',
#     'endseq'],
#    ['startseq', 'brown', 'puppy', 'chewing', 'on', 'stick', 'endseq'],
#    ['startseq',
#     'dog',
#     'with',
#     'big',
#     'ears',
#     'is',
#     'holding',
#     'small',
#     'stick',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq', 'puppy', 'has', 'stick', 'in', 'its', 'mouth', 'endseq'],
#    ['startseq',
#     'puppy',
#     'with',
#     'big',
#     'ears',
#     'chewing',
#     'on',
#     'stick',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '862156271_3eacea90a8': ([['startseq',
#     'girls',
#     'with',
#     'orange',
#     'hair',
#     'standing',
#     'on',
#     'the',
#     'street',
#     'with',
#     'some',
#     'kind',
#     'of',
#     'bottle',
#     'in',
#     'their',
#     'hand',
#     'endseq'],
#    ['startseq', 'two', 'girls', 'walking', 'in', 'the', 'street', 'endseq'],
#    ['startseq',
#     'two',
#     'girls',
#     'walking',
#     'next',
#     'to',
#     'each',
#     'other',
#     'and',
#     'talking',
#     'endseq'],
#    ['startseq',
#     'two',
#     'teenage',
#     'girls',
#     'dressed',
#     'like',
#     'hippies',
#     'walk',
#     'and',
#     'talk',
#     'endseq'],
#    ['startseq',
#     'two',
#     'women',
#     'one',
#     'with',
#     'head',
#     'bandanna',
#     'are',
#     'standing',
#     'next',
#     'to',
#     'each',
#     'other',
#     'while',
#     'one',
#     'holds',
#     'bottle',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'is',
#    'standing',
#    'on']),
#  '862177617_c2c0581075': ([['startseq',
#     'girl',
#     'is',
#     'wearing',
#     'blue',
#     'wig',
#     'under',
#     'brown',
#     'hooded',
#     'jacket',
#     'endseq'],
#    ['startseq',
#     'man',
#     'wears',
#     'an',
#     'interesting',
#     'blue',
#     'wig',
#     'in',
#     'public',
#     'endseq'],
#    ['startseq',
#     'person',
#     'with',
#     'blue',
#     'hair',
#     'baseball',
#     'cap',
#     'and',
#     'hood',
#     'on',
#     'stands',
#     'outdoors',
#     'in',
#     'crowd',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'brown',
#     'coat',
#     'and',
#     'sunglasses',
#     'wears',
#     'blue',
#     'wig',
#     'and',
#     'ball',
#     'cap',
#     'endseq'],
#    ['startseq',
#     'one',
#     'person',
#     'in',
#     'crowd',
#     'of',
#     'people',
#     'wearing',
#     'blue',
#     'wig',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt']),
#  '862187579_9faf4a51e0': ([['startseq',
#     'man',
#     'wearing',
#     'glasses',
#     'is',
#     'staring',
#     'off',
#     'into',
#     'space',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'glasses',
#     'is',
#     'standing',
#     'in',
#     'front',
#     'of',
#     'building',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'sunglasses',
#     'looking',
#     'straight',
#     'ahead',
#     'endseq'],
#    ['startseq',
#     'man',
#     'with',
#     'sunglasses',
#     'standing',
#     'by',
#     'white',
#     'and',
#     'red',
#     'building',
#     'with',
#     'very',
#     'blue',
#     'sky',
#     'above',
#     'endseq'],
#    ['startseq',
#     'the',
#     'man',
#     'wearing',
#     'the',
#     'purple',
#     'shirt',
#     'is',
#     'in',
#     'the',
#     'shadows',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'and',
#    'hat',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black',
#    'shirt',
#    'and',
#    'black']),
#  '874665322_9ad05c4065': ([['startseq',
#     'brown',
#     'dog',
#     'is',
#     'playing',
#     'outside',
#     'in',
#     'grassy',
#     'area',
#     'endseq'],
#    ['startseq',
#     'brown',
#     'dog',
#     'wearing',
#     'blue',
#     'harness',
#     'jumps',
#     'over',
#     'the',
#     'grassy',
#     'field',
#     'endseq'],
#    ['startseq',
#     'brown',
#     'dog',
#     'with',
#     'blue',
#     'bandanna',
#     'is',
#     'jumping',
#     'over',
#     'grass',
#     'endseq'],
#    ['startseq', 'dog', 'is', 'jumping', 'in', 'the', 'grass', 'endseq'],
#    ['startseq', 'dog', 'runs', 'through', 'the', 'grass', 'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '90011335_cfdf9674c2': ([['startseq',
#     'boat',
#     'is',
#     'on',
#     'the',
#     'water',
#     'with',
#     'mountains',
#     'in',
#     'the',
#     'background',
#     'endseq'],
#    ['startseq', 'boat', 'on', 'the', 'water', 'endseq'],
#    ['startseq', 'lone', 'boat', 'sitting', 'in', 'the', 'water', 'endseq'],
#    ['startseq',
#     'white',
#     'boat',
#     'on',
#     'glassy',
#     'water',
#     'with',
#     'mountains',
#     'in',
#     'the',
#     'background',
#     'endseq'],
#    ['startseq',
#     'this',
#     'is',
#     'boat',
#     'on',
#     'the',
#     'water',
#     'with',
#     'mountains',
#     'in',
#     'the',
#     'background',
#     'endseq']],
#   ['startseq',
#    'man',
#    'is',
#    'swimming',
#    'underwater',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '911527312_f81ee36b97': ([['startseq',
#     'boy',
#     'wearing',
#     'red',
#     'crocs',
#     'climbing',
#     'tree',
#     'endseq'],
#    ['startseq',
#     'boy',
#     'wearing',
#     'red',
#     'shoes',
#     'is',
#     'climbing',
#     'in',
#     'tree',
#     'endseq'],
#    ['startseq',
#     'child',
#     'wearing',
#     'red',
#     'shoes',
#     'climbing',
#     'tree',
#     'endseq'],
#    ['startseq',
#     'small',
#     'child',
#     'is',
#     'in',
#     'tree',
#     'wearing',
#     'red',
#     'shoes',
#     'endseq'],
#    ['startseq',
#     'young',
#     'boy',
#     'wearing',
#     'red',
#     'croc',
#     'sandals',
#     'climbs',
#     'tree',
#     'with',
#     'healthy',
#     'green',
#     'leaves',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'with',
#    'the',
#    'camera',
#    'endseq']),
#  '911795495_342bb15b97': ([['startseq',
#     'girl',
#     'sits',
#     'on',
#     'swing',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'wearing',
#     'an',
#     'orange',
#     'shirt',
#     'holds',
#     'onto',
#     'poles',
#     'and',
#     'looks',
#     'down',
#     'endseq'],
#    ['startseq',
#     'soft',
#     'focus',
#     'picture',
#     'of',
#     'little',
#     'girl',
#     'wearing',
#     'an',
#     'orange',
#     'sweater',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'with',
#     'long',
#     'brown',
#     'hair',
#     'holding',
#     'black',
#     'and',
#     'red',
#     'striped',
#     'stick',
#     'endseq'],
#    ['startseq',
#     'the',
#     'girl',
#     'in',
#     'the',
#     'red',
#     'shirt',
#     'smiles',
#     'on',
#     'the',
#     'swing',
#     'endseq']],
#   ['startseq',
#    'little',
#    'boy',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'grass',
#    'endseq']),
#  '93922153_8d831f7f01': ([['startseq',
#     'woman',
#     'climbs',
#     'up',
#     'cliff',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'rock',
#     'climber',
#     'scales',
#     'cliff',
#     'far',
#     'above',
#     'pastures',
#     'endseq'],
#    ['startseq', 'woman', 'rockclimbing', 'on', 'cliff', 'endseq'],
#    ['startseq', 'woman', 'rockclimbs', 'in', 'rural', 'area', 'endseq'],
#    ['startseq',
#     'woman',
#     'climbing',
#     'cliff',
#     'in',
#     'rural',
#     'area',
#     'endseq']],
#   ['startseq',
#    'man',
#    'is',
#    'riding',
#    'bicycle',
#    'on',
#    'the',
#    'side',
#    'of',
#    'mountain',
#    'endseq']),
#  '947664583_7c63172366': ([['startseq',
#     'child',
#     'jumps',
#     'into',
#     'pool',
#     'as',
#     'man',
#     'looks',
#     'on',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'with',
#     'swimmies',
#     'on',
#     'is',
#     'jumping',
#     'into',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'wearing',
#     'orange',
#     'arm',
#     'floats',
#     'jumping',
#     'into',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'little',
#     'girl',
#     'with',
#     'inflatable',
#     'armbands',
#     'is',
#     'jumping',
#     'into',
#     'the',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'with',
#     'water',
#     'wings',
#     'leaps',
#     'into',
#     'crowded',
#     'pool',
#     'endseq']],
#   ['startseq',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '957682378_46c3b07bcd': ([['startseq',
#     'brown',
#     'dog',
#     'and',
#     'black',
#     'dog',
#     'run',
#     'into',
#     'each',
#     'other',
#     'in',
#     'the',
#     'grass',
#     'endseq'],
#    ['startseq',
#     'brown',
#     'dog',
#     'is',
#     'grabbing',
#     'the',
#     'collar',
#     'of',
#     'black',
#     'dog',
#     'endseq'],
#    ['startseq',
#     'dark',
#     'black',
#     'dog',
#     'is',
#     'playing',
#     'with',
#     'light',
#     'brown',
#     'dog',
#     'in',
#     'backyard',
#     'endseq'],
#    ['startseq', 'two', 'dogs', 'are', 'wrestling', 'in', 'field', 'endseq'],
#    ['startseq',
#     'two',
#     'dogs',
#     'are',
#     'wrestling',
#     'in',
#     'the',
#     'park',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq']),
#  '96978713_775d66a18d': ([['startseq',
#     'hikers',
#     'cross',
#     'bridge',
#     'over',
#     'fast',
#     'moving',
#     'stream',
#     'and',
#     'rocky',
#     'scenery',
#     'endseq'],
#    ['startseq',
#     'people',
#     'crossing',
#     'long',
#     'bridge',
#     'over',
#     'canyon',
#     'with',
#     'river',
#     'endseq'],
#    ['startseq',
#     'people',
#     'walk',
#     'across',
#     'rope',
#     'bridge',
#     'over',
#     'rocky',
#     'stream',
#     'endseq'],
#    ['startseq',
#     'some',
#     'hikers',
#     'are',
#     'crossing',
#     'wood',
#     'and',
#     'wire',
#     'bridge',
#     'over',
#     'river',
#     'endseq'],
#    ['startseq',
#     'three',
#     'people',
#     'are',
#     'looking',
#     'across',
#     'rope',
#     'and',
#     'wood',
#     'bridge',
#     'over',
#     'river',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'beach',
#    'endseq']),
#  '97105139_fae46fe8ef': ([['startseq',
#     'two',
#     'men',
#     'in',
#     'ethnic',
#     'dress',
#     'standing',
#     'in',
#     'barren',
#     'landscape',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'in',
#     'keffiyahs',
#     'stand',
#     'next',
#     'to',
#     'car',
#     'in',
#     'the',
#     'desert',
#     'and',
#     'wave',
#     'at',
#     'passing',
#     'vehicle',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'in',
#     'robes',
#     'wave',
#     'at',
#     'an',
#     'approaching',
#     'jeep',
#     'traveling',
#     'through',
#     'the',
#     'sand',
#     'endseq'],
#    ['startseq',
#     'two',
#     'men',
#     'in',
#     'traditional',
#     'arab',
#     'dress',
#     'standing',
#     'near',
#     'car',
#     'wave',
#     'at',
#     'an',
#     'suv',
#     'in',
#     'the',
#     'desert',
#     'endseq'],
#    ['startseq',
#     'two',
#     'people',
#     'with',
#     'head',
#     'coverings',
#     'stand',
#     'in',
#     'sandy',
#     'field',
#     'endseq']],
#   ['startseq',
#    'man',
#    'in',
#    'black',
#    'shirt',
#    'and',
#    'hat',
#    'is',
#    'standing',
#    'on',
#    'the',
#    'street',
#    'endseq']),
#  '973827791_467d83986e': ([['startseq',
#     'little',
#     'kid',
#     'splashes',
#     'around',
#     'in',
#     'the',
#     'kiddie',
#     'pool',
#     'while',
#     'lady',
#     'watches',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'dumping',
#     'water',
#     'on',
#     'small',
#     'child',
#     'who',
#     'is',
#     'in',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'is',
#     'throwing',
#     'bucket',
#     'of',
#     'water',
#     'over',
#     'baby',
#     'in',
#     'the',
#     'paddling',
#     'pool',
#     'endseq'],
#    ['startseq',
#     'woman',
#     'is',
#     'throwing',
#     'water',
#     'on',
#     'child',
#     'in',
#     'plastic',
#     'swimming',
#     'pool',
#     'in',
#     'rural',
#     'area',
#     'endseq'],
#    ['startseq',
#     'child',
#     'slides',
#     'into',
#     'wading',
#     'pool',
#     'full',
#     'of',
#     'water',
#     'while',
#     'an',
#     'adult',
#     'tosses',
#     'bucket',
#     'of',
#     'water',
#     'on',
#     'them',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'pink',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '97577988_65e2eae14a': ([['startseq',
#     'man',
#     'mountain',
#     'climbing',
#     'up',
#     'an',
#     'icy',
#     'mountain',
#     'endseq'],
#    ['startseq',
#     'an',
#     'climber',
#     'is',
#     'ascending',
#     'an',
#     'ice',
#     'covered',
#     'rock',
#     'face',
#     'endseq'],
#    ['startseq',
#     'person',
#     'in',
#     'orange',
#     'climbs',
#     'sheer',
#     'cliff',
#     'face',
#     'covered',
#     'in',
#     'snow',
#     'and',
#     'ice',
#     'endseq'],
#    ['startseq',
#     'person',
#     'in',
#     'yellow',
#     'jacket',
#     'is',
#     'climbing',
#     'up',
#     'snow',
#     'covered',
#     'rocks',
#     'endseq'],
#    ['startseq',
#     'there',
#     'is',
#     'climber',
#     'scaling',
#     'snowy',
#     'mountainside',
#     'endseq']],
#   ['startseq', 'man', 'is', 'climbing', 'up', 'rock', 'face', 'endseq']),
#  '989754491_7e53fb4586': ([['startseq',
#     'girl',
#     'in',
#     'pool',
#     'wearing',
#     'goggles',
#     'and',
#     'surrounded',
#     'by',
#     'other',
#     'children',
#     'endseq'],
#    ['startseq',
#     'girl',
#     'in',
#     'green',
#     'goggles',
#     'in',
#     'pool',
#     'with',
#     'three',
#     'other',
#     'children',
#     'endseq'],
#    ['startseq',
#     'red',
#     'haired',
#     'girl',
#     'making',
#     'peace',
#     'sign',
#     'is',
#     'wearing',
#     'neon',
#     'green',
#     'glasses',
#     'and',
#     'floaties',
#     'and',
#     'playing',
#     'in',
#     'the',
#     'pool',
#     'with',
#     'other',
#     'kids',
#     'endseq'],
#    ['startseq',
#     'redheaded',
#     'girl',
#     'offers',
#     'the',
#     'peace',
#     'sign',
#     'as',
#     'she',
#     'swims',
#     'in',
#     'the',
#     'pool',
#     'with',
#     'floaties',
#     'endseq'],
#    ['startseq',
#     'young',
#     'girl',
#     'with',
#     'goggles',
#     'and',
#     'floaties',
#     'poses',
#     'for',
#     'the',
#     'camera',
#     'as',
#     'she',
#     'plays',
#     'in',
#     'pool',
#     'endseq']],
#   ['startseq',
#    'young',
#    'boy',
#    'in',
#    'red',
#    'shirt',
#    'is',
#    'playing',
#    'in',
#    'the',
#    'water',
#    'endseq']),
#  '989851184_9ef368e520': ([['startseq',
#     'black',
#     'dog',
#     'has',
#     'dumbbell',
#     'in',
#     'his',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'has',
#     'dumbbell',
#     'in',
#     'his',
#     'mouth',
#     'looking',
#     'at',
#     'the',
#     'person',
#     'wearing',
#     'blue',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'holding',
#     'weight',
#     'in',
#     'its',
#     'mouth',
#     'stands',
#     'next',
#     'to',
#     'person',
#     'endseq'],
#    ['startseq',
#     'black',
#     'dog',
#     'holds',
#     'small',
#     'white',
#     'dumbbell',
#     'in',
#     'its',
#     'mouth',
#     'endseq'],
#    ['startseq',
#     'the',
#     'black',
#     'dog',
#     'has',
#     'toy',
#     'in',
#     'its',
#     'mouth',
#     'and',
#     'person',
#     'stands',
#     'nearby',
#     'endseq']],
#   ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq'])}

# %%
vallist[126]
# Out:
# '3223973114_6c15538ce9'

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('Flickr8k/Flicker8k_Dataset/3223973114_6c15538ce9.jpg')
img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
plt.imshow(img)

# %%
rd_val['3223973114_6c15538ce9']
# Out:
# ([['startseq', 'big', 'brown', 'dog', 'running', 'endseq'],
#   ['startseq', 'brindle', 'do', 'runs', 'through', 'grassy', 'yard', 'endseq'],
#   ['startseq', 'brown', 'dog', 'runs', 'outdoors', 'endseq'],
#   ['startseq', 'grayhound', 'dog', 'is', 'sprinting', 'endseq'],
#   ['startseq', 'dog', 'running', 'in', 'yard', 'endseq']],
#  ['startseq', 'dog', 'is', 'running', 'through', 'the', 'grass', 'endseq'])

# %%
pickle.dump(rd_val,open('rd_IncRes_val.pkl','wb'))

# %%
uploadId = '1Hw09omY9-FIa_Z4o0PswO-Xx3Gb6DHU3'
uploaded = drive.CreateFile({'parents':[{'id': uploadId}] , 'title' : 'rd_IncRes_val.pkl'})
uploaded.SetContentFile('rd_IncRes_val.pkl')
uploaded.Upload()

# %%
len(rd_val)
# Out:
# 1000
