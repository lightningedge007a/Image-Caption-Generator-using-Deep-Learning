# %%
import numpy as np
import cv2
import pickle

# %%
path='ImgCap_V0/Code/Flickr8k/Flicker8k_Dataset/'

# %%
import os
len(os.listdir(path))
# Out:
# 8091

# %%
trainset=pickle.load(open('ImgCap_V3_ResNet/train_set.pkl','rb'))
testset=pickle.load(open('ImgCap_V3_ResNet/test_set.pkl','rb'))
validtnset=pickle.load(open('ImgCap_V3_ResNet/validtn_set.pkl','rb'))
len(trainset),len(testset),len(validtnset)
# Out:
# (6000, 1000, 1000)

# %%
import random
rl=random.sample(range(1, 1000), 10)
rl
# Out:
# [147, 666, 468, 329, 945, 934, 768, 251, 163, 715]

# %%
test=list(testset)
test[rl[0]]
# Out:
# '757332692_6866ae545c'

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread(path+test[rl[0]]+'.jpg')
plt.imshow(img)

# %%
'219070971_ae43410b9e' in testset
# Out:
# True

# %%
#219070971_ae43410b9e
img=cv2.imread(path+'219070971_ae43410b9e.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
actual=pickle.load(open('ImgCap_V3_ResNet/actual_test.pkl','rb'))
predicted=pickle.load(open('ImgCap_V3_ResNet/predicted_test.pkl','rb'))
len(actual),len(predicted)
# Out:
# (1000, 1000)

# %%
actual[147]
# Out:
# [['startseq',
#   'dirt',
#   'biker',
#   'pushes',
#   'his',
#   'motorcycle',
#   'up',
#   'rock',
#   'while',
#   'another',
#   'rider',
#   'watches',
#   'endseq'],
#  ['startseq',
#   'man',
#   'in',
#   'red',
#   'on',
#   'dirt',
#   'bike',
#   'struggles',
#   'up',
#   'rock',
#   'while',
#   'another',
#   'man',
#   'in',
#   'red',
#   'watches',
#   'endseq'],
#  ['startseq',
#   'man',
#   'in',
#   'red',
#   'pushes',
#   'his',
#   'motocross',
#   'bike',
#   'up',
#   'rock',
#   'endseq'],
#  ['startseq',
#   'man',
#   'is',
#   'looking',
#   'on',
#   'as',
#   'another',
#   'man',
#   'attempts',
#   'to',
#   'climb',
#   'small',
#   'boulder',
#   'with',
#   'his',
#   'dirt',
#   'bike',
#   'endseq'],
#  ['startseq',
#   'redclad',
#   'man',
#   'rides',
#   'bike',
#   'through',
#   'rocky',
#   'ground',
#   'while',
#   'another',
#   'man',
#   'looks',
#   'on',
#   'endseq']]

# %%
predicted[147]
# Out:
# ['startseq',
#  'man',
#  'in',
#  'red',
#  'shirt',
#  'is',
#  'riding',
#  'bike',
#  'on',
#  'dirt',
#  'road',
#  'endseq']

# %%
#3385593926_d3e9c21170
test[0]
# Out:
# '3627011534_485f667b10'

# %%
'3385593926_d3e9c21170' in testset
# Out:
# True

# %%
predicted[0]
# Out:
# ['startseq',
#  'man',
#  'in',
#  'red',
#  'shirt',
#  'is',
#  'sitting',
#  'on',
#  'the',
#  'street',
#  'endseq']

# %%
actual[0]
# Out:
# [['startseq',
#   'blond',
#   'woman',
#   'in',
#   'blue',
#   'shirt',
#   'appears',
#   'to',
#   'wait',
#   'for',
#   'ride',
#   'endseq'],
#  ['startseq',
#   'blond',
#   'woman',
#   'is',
#   'on',
#   'the',
#   'street',
#   'hailing',
#   'taxi',
#   'endseq'],
#  ['startseq',
#   'woman',
#   'is',
#   'signaling',
#   'is',
#   'to',
#   'traffic',
#   'as',
#   'seen',
#   'from',
#   'behind',
#   'endseq'],
#  ['startseq',
#   'woman',
#   'with',
#   'blonde',
#   'hair',
#   'wearing',
#   'blue',
#   'tube',
#   'top',
#   'is',
#   'waving',
#   'on',
#   'the',
#   'side',
#   'of',
#   'the',
#   'street',
#   'endseq'],
#  ['startseq',
#   'the',
#   'woman',
#   'in',
#   'the',
#   'blue',
#   'dress',
#   'is',
#   'holding',
#   'out',
#   'her',
#   'arm',
#   'at',
#   'oncoming',
#   'traffic',
#   'endseq']]
